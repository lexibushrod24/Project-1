# %%
# !pwd
# Out:
# /Users/moussadoumbia/Desktop/23ACADEMY/I.T/FALL22_DS

# %% [markdown]
# # FIRST GROUP PROJECT SPRING 2024

# %%
#import the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import warnings

# %%
warnings.simplefilter('ignore')

# %%
#Convert the dataset onto a pandas dataframe
# df = pd.read_csv('survey_results_public.csv')

# %%
df = pd.read_csv('survey_results_public_2019.csv')

# %%
#print the first five rows of the dataframe
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State UK_Country  \
# 0                                           Slovakia      NaN        NaN
# 1                                        Netherlands      NaN        NaN
# 2                                 Russian Federation      NaN        NaN
# 3                                            Austria      NaN        NaN
# 4  United Kingdom of Great Britain and Northern I...      NaN    England
#
#                                              EdLevel     Age1stCode  \
# 0  Secondary school (e.g. American high school, G...  18 - 24 years
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 2       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 3    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  11 - 17 years
# 4    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)   5 - 10 years
#
#                                            LearnCode YearsCode YearsCodePro  \
# 0  Coding Bootcamp;Other online resources (ex: vi...       NaN          NaN
# 1  Other online resources (ex: videos, blogs, etc...         7          NaN
# 2  Other online resources (ex: videos, blogs, etc...       NaN          NaN
# 3                                                NaN       NaN          NaN
# 4                            Friend or family member        17           10
#
#                                              DevType  \
# 0                                  Developer, mobile
# 1                                                NaN
# 2                                                NaN
# 3                               Developer, front-end
# 4  Developer, desktop or enterprise applications;...
#
#                                              OrgSize             Currency  \
# 0                                 20 to 99 employees    EUR European Euro
# 1                                                NaN                  NaN
# 2                                                NaN                  NaN
# 3                               100 to 499 employees    EUR European Euro
# 4  Just me - I am a freelancer, sole proprietor, ...  GBP\tPound sterling
#
#    CompTotal CompFreq                         LanguageHaveWorkedWith  \
# 0     4800.0  Monthly  C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 1        NaN      NaN                              JavaScript;Python
# 2        NaN      NaN                       Assembly;C;Python;R;Rust
# 3        NaN  Monthly                          JavaScript;TypeScript
# 4        NaN      NaN                 Bash/Shell;HTML/CSS;Python;SQL
#
#            LanguageWantToWorkWith          DatabaseHaveWorkedWith  \
# 0                           Swift               PostgreSQL;SQLite
# 1                             NaN                      PostgreSQL
# 2               Julia;Python;Rust                          SQLite
# 3           JavaScript;TypeScript                             NaN
# 4  Bash/Shell;HTML/CSS;Python;SQL  Elasticsearch;PostgreSQL;Redis
#
#                      DatabaseWantToWorkWith PlatformHaveWorkedWith  \
# 0                                    SQLite                    NaN
# 1                                       NaN                    NaN
# 2                                    SQLite                 Heroku
# 3                                       NaN                    NaN
# 4  Cassandra;Elasticsearch;PostgreSQL;Redis                    NaN
#
#   PlatformWantToWorkWith WebframeHaveWorkedWith WebframeWantToWorkWith  \
# 0                    NaN        Laravel;Symfony                    NaN
# 1                    NaN   Angular;Flask;Vue.js                    NaN
# 2                    NaN                  Flask                  Flask
# 3                    NaN         Angular;jQuery         Angular;jQuery
# 4                    NaN                  Flask                  Flask
#
#                   MiscTechHaveWorkedWith  \
# 0                                    NaN
# 1                                Cordova
# 2  NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                    NaN
# 4       Apache Spark;Hadoop;NumPy;Pandas
#
#                         MiscTechWantToWorkWith     ToolsTechHaveWorkedWith  \
# 0                                          NaN                         NaN
# 1                                          NaN             Docker;Git;Yarn
# 2  Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch                         NaN
# 3                                          NaN                         NaN
# 4                          Hadoop;NumPy;Pandas  Docker;Git;Kubernetes;Yarn
#
#       ToolsTechWantToWorkWith  \
# 0                         NaN
# 1                         Git
# 2                         NaN
# 3                         NaN
# 4  Docker;Git;Kubernetes;Yarn
#
#                         NEWCollabToolsHaveWorkedWith  \
# 0                                     PHPStorm;Xcode
# 1          Android Studio;IntelliJ;Notepad++;PyCharm
# 2  IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 3                                                NaN
# 4         Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
#
#                         NEWCollabToolsWantToWorkWith        OpSys  \
# 0                                         Atom;Xcode        MacOS
# 1                                                NaN      Windows
# 2  IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 3                                                NaN      Windows
# 4  Atom;IPython/Jupyter;Notepad++;PyCharm;Vim;Vis...  Linux-based
#
#                                             NEWStuck  \
# 0  Call a coworker or friend;Visit Stack Overflow...
# 1                     Visit Stack Overflow;Google it
# 2  Visit Stack Overflow;Google it;Watch help / tu...
# 3  Call a coworker or friend;Visit Stack Overflow...
# 4  Visit Stack Overflow;Go for a walk or other ph...
#
#                       NEWSOSites             SOVisitFreq SOAccount  \
# 0                 Stack Overflow  Multiple times per day       Yes
# 1                 Stack Overflow   Daily or almost daily       Yes
# 2  Stack Overflow;Stack Exchange  Multiple times per day       Yes
# 3                 Stack Overflow   Daily or almost daily       Yes
# 4  Stack Overflow;Stack Exchange   Daily or almost daily       Yes
#
#                         SOPartFreq           SOComm NEWOtherComms  \
# 0  A few times per month or weekly  Yes, definitely            No
# 1            Daily or almost daily  Yes, definitely            No
# 2           Multiple times per day  Yes, definitely           Yes
# 3            Daily or almost daily          Neutral            No
# 4             A few times per week    Yes, somewhat            No
#
#                Age Gender Trans                Sexuality  \
# 0  25-34 years old    Man    No  Straight / Heterosexual
# 1  18-24 years old    Man    No  Straight / Heterosexual
# 2  18-24 years old    Man    No        Prefer not to say
# 3  35-44 years old    Man    No  Straight / Heterosexual
# 4  25-34 years old    Man    No                      NaN
#
#                       Ethnicity                Accessibility  \
# 0  White or of European descent            None of the above
# 1  White or of European descent            None of the above
# 2             Prefer not to say            None of the above
# 3  White or of European descent  I am deaf / hard of hearing
# 4  White or of European descent            None of the above
#
#         MentalHealth           SurveyLength                  SurveyEase  \
# 0  None of the above  Appropriate in length                        Easy
# 1  None of the above  Appropriate in length                        Easy
# 2  None of the above  Appropriate in length                        Easy
# 3                NaN  Appropriate in length  Neither easy nor difficult
# 4                NaN  Appropriate in length                        Easy
#
#    ConvertedCompYearly
# 0              62268.0
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
# 2                      Employed full-time                Thailand
# 3                      Employed full-time           United States
# 4                      Employed full-time                 Ukraine
#
#           Student                                            EdLevel  \
# 0              No                          Primary/elementary school
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
# 2              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                       UndergradMajor  ...  \
# 0                                                NaN  ...
# 1                                                NaN  ...
# 2                      Web development or web design  ...
# 3  Computer science, computer engineering, or sof...  ...
# 4  Computer science, computer engineering, or sof...  ...
#
#                              WelcomeChange  \
# 0  Just as welcome now as I felt last year
# 1  Just as welcome now as I felt last year
# 2  Just as welcome now as I felt last year
# 3  Just as welcome now as I felt last year
# 4  Just as welcome now as I felt last year
#
#                                         SONewContent   Age Gender Trans  \
# 0  Tech articles written by other developers;Indu...  14.0    Man    No
# 1  Tech articles written by other developers;Indu...  19.0    Man    No
# 2  Tech meetups or events in your area;Courses on...  28.0    Man    No
# 3  Tech articles written by other developers;Indu...  22.0    Man    No
# 4  Tech meetups or events in your area;Courses on...  30.0    Man    No
#
#                  Sexuality                                 Ethnicity  \
# 0  Straight / Heterosexual                                       NaN
# 1  Straight / Heterosexual                                       NaN
# 2  Straight / Heterosexual                                       NaN
# 3  Straight / Heterosexual              White or of European descent
# 4  Straight / Heterosexual  White or of European descent;Multiracial
#
#   Dependents           SurveyLength                  SurveyEase
# 0         No  Appropriate in length  Neither easy nor difficult
# 1         No  Appropriate in length  Neither easy nor difficult
# 2        Yes  Appropriate in length  Neither easy nor difficult
# 3         No  Appropriate in length                        Easy
# 4         No  Appropriate in length                        Easy
#
# [5 rows x 85 columns]

# %%
#provide some insight about your data
# Out:
#          ResponseId     CompTotal  ConvertedCompYearly
# count  83439.000000  4.718300e+04         4.684400e+04
# mean   41720.000000  2.119407e+69         1.184262e+05
# std    24086.908893  4.603702e+71         5.272944e+05
# min        1.000000  0.000000e+00         1.000000e+00
# 25%    20860.500000  1.600000e+04         2.702500e+04
# 50%    41720.000000  6.700000e+04         5.621100e+04
# 75%    62579.500000  1.400000e+05         1.000000e+05
# max    83439.000000  1.000000e+74         4.524131e+07

# %%
aggregations = ['count', 'mean', 'std', 'min', (lambda x: x.quantile(0.25)), 'median', (lambda x: x.quantile(0.75)), 'max']                                                 

aggregations_renamed = ['count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max']

agg_df = df[["Respondent", "CompTotal", "ConvertedComp"]].agg(aggregations)
agg_df.index = aggregations_renamed

# %%
agg_df
# Out:
#          Respondent     CompTotal  ConvertedComp
# count  88883.000000  5.594500e+04   5.582300e+04
# mean   44442.000000  5.519014e+11   1.271107e+05
# std    25658.456325  7.331926e+13   2.841523e+05
# min        1.000000  0.000000e+00   0.000000e+00
# 25%    22221.500000  2.000000e+04   2.577750e+04
# 50%    44442.000000  6.200000e+04   5.728700e+04
# 75%    66662.500000  1.200000e+05   1.000000e+05
# max    88883.000000  1.000000e+16   2.000000e+06

# %%
#set the maximum number of columns to 85

# %%
# Out:
#    ResponseId                              MainBranch  \
# 0           1          I am a developer by profession
# 1           2  I am a student who is learning to code
#
#                                           Employment      Country US_State  \
# 0  Independent contractor, freelancer, or self-em...     Slovakia      NaN
# 1                                 Student, full-time  Netherlands      NaN
#
#   UK_Country                                            EdLevel  \
# 0        NaN  Secondary school (e.g. American high school, G...
# 1        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#       Age1stCode                                          LearnCode YearsCode  \
# 0  18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...       NaN
# 1  11 - 17 years  Other online resources (ex: videos, blogs, etc...         7
#
#   YearsCodePro            DevType             OrgSize           Currency  \
# 0          NaN  Developer, mobile  20 to 99 employees  EUR European Euro
# 1          NaN                NaN                 NaN                NaN
#
#    CompTotal CompFreq                         LanguageHaveWorkedWith  \
# 0     4800.0  Monthly  C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 1        NaN      NaN                              JavaScript;Python
#
#   LanguageWantToWorkWith DatabaseHaveWorkedWith DatabaseWantToWorkWith  \
# 0                  Swift      PostgreSQL;SQLite                 SQLite
# 1                    NaN             PostgreSQL                    NaN
#
#   PlatformHaveWorkedWith PlatformWantToWorkWith WebframeHaveWorkedWith  \
# 0                    NaN                    NaN        Laravel;Symfony
# 1                    NaN                    NaN   Angular;Flask;Vue.js
#
#   WebframeWantToWorkWith MiscTechHaveWorkedWith MiscTechWantToWorkWith  \
# 0                    NaN                    NaN                    NaN
# 1                    NaN                Cordova                    NaN
#
#   ToolsTechHaveWorkedWith ToolsTechWantToWorkWith  \
# 0                     NaN                     NaN
# 1         Docker;Git;Yarn                     Git
#
#                 NEWCollabToolsHaveWorkedWith NEWCollabToolsWantToWorkWith  \
# 0                             PHPStorm;Xcode                   Atom;Xcode
# 1  Android Studio;IntelliJ;Notepad++;PyCharm                          NaN
#
#      OpSys                                           NEWStuck      NEWSOSites  \
# 0    MacOS  Call a coworker or friend;Visit Stack Overflow...  Stack Overflow
# 1  Windows                     Visit Stack Overflow;Google it  Stack Overflow
#
#               SOVisitFreq SOAccount                       SOPartFreq  \
# 0  Multiple times per day       Yes  A few times per month or weekly
# 1   Daily or almost daily       Yes            Daily or almost daily
#
#             SOComm NEWOtherComms              Age Gender Trans  \
# 0  Yes, definitely            No  25-34 years old    Man    No
# 1  Yes, definitely            No  18-24 years old    Man    No
#
#                  Sexuality                     Ethnicity      Accessibility  \
# 0  Straight / Heterosexual  White or of European descent  None of the above
# 1  Straight / Heterosexual  White or of European descent  None of the above
#
#         MentalHealth           SurveyLength SurveyEase  ConvertedCompYearly
# 0  None of the above  Appropriate in length       Easy              62268.0
# 1  None of the above  Appropriate in length       Easy                  NaN

# %%
pd.set_option('display.max_columns', 85)

df.iloc[0:2]
# Out:
#    Respondent                              MainBranch Hobbyist  \
# 0           1  I am a student who is learning to code      Yes
# 1           2  I am a student who is learning to code       No
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
#
#           Student                                            EdLevel  \
# 0              No                          Primary/elementary school
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
#
#   UndergradMajor                                           EduOther OrgSize  \
# 0            NaN  Taught yourself a new language, framework, or ...     NaN
# 1            NaN  Taken an online course in programming or softw...     NaN
#
#                                              DevType YearsCode Age1stCode  \
# 0                                                NaN         4         10
# 1  Developer, desktop or enterprise applications;...       NaN         17
#
#   YearsCodePro CareerSat JobSat MgrIdiot MgrMoney MgrWant  \
# 0          NaN       NaN    NaN      NaN      NaN     NaN
# 1          NaN       NaN    NaN      NaN      NaN     NaN
#
#                            JobSeek          LastHireDate LastInt FizzBuzz  \
# 0                              NaN                   NaN     NaN      NaN
# 1  I am actively looking for a job  I've never had a job     NaN      NaN
#
#                                           JobFactors  \
# 0                                                NaN
# 1  Financial performance or funding status of the...
#
#                                         ResumeUpdate CurrencySymbol  \
# 0                                                NaN            NaN
# 1  Something else changed (education, award, medi...            NaN
#
#   CurrencyDesc  CompTotal CompFreq  ConvertedComp  WorkWeekHrs WorkPlan  \
# 0          NaN        NaN      NaN            NaN          NaN      NaN
# 1          NaN        NaN      NaN            NaN          NaN      NaN
#
#   WorkChallenge WorkRemote WorkLoc ImpSyn CodeRev  CodeRevHrs UnitTests  \
# 0           NaN        NaN     NaN    NaN     NaN         NaN       NaN
# 1           NaN        NaN     NaN    NaN     NaN         NaN       NaN
#
#   PurchaseHow PurchaseWhat               LanguageWorkedWith  \
# 0         NaN          NaN  HTML/CSS;Java;JavaScript;Python
# 1         NaN          NaN              C++;HTML/CSS;Python
#
#                             LanguageDesireNextYear DatabaseWorkedWith  \
# 0  C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL             SQLite
# 1                      C++;HTML/CSS;JavaScript;SQL                NaN
#
#   DatabaseDesireNextYear PlatformWorkedWith   PlatformDesireNextYear  \
# 0                  MySQL      MacOS;Windows  Android;Arduino;Windows
# 1                  MySQL            Windows                  Windows
#
#   WebFrameWorkedWith WebFrameDesireNextYear MiscTechWorkedWith  \
# 0       Django;Flask           Flask;jQuery            Node.js
# 1             Django                 Django                NaN
#
#   MiscTechDesireNextYear                  DevEnviron    OpSys  \
# 0                Node.js  IntelliJ;Notepad++;PyCharm  Windows
# 1                    NaN                Atom;PyCharm  Windows
#
#                 Containers BlockchainOrg  \
# 0  I do not use containers           NaN
# 1  I do not use containers           NaN
#
#                                         BlockchainIs BetterLife  \
# 0                                                NaN        Yes
# 1  Useful across many domains and could change ma...        Yes
#
#                                    ITperson OffOn SocialMedia Extraversion  \
# 0  Fortunately, someone else has that title   Yes     Twitter       Online
# 1                                       Yes   Yes   Instagram       Online
#
#   ScreenName SOVisit1st                      SOVisitFreq  \
# 0   Username       2017  A few times per month or weekly
# 1   Username       2017            Daily or almost daily
#
#                                            SOVisitTo        SOFindAnswer  \
# 0  Find answers to specific questions;Learn how t...  3-5 times per week
# 1  Find answers to specific questions;Learn how t...  3-5 times per week
#
#                       SOTimeSaved  SOHowMuchTime SOAccount  \
# 0  Stack Overflow was much faster  31-60 minutes        No
# 1  Stack Overflow was much faster  11-30 minutes       Yes
#
#                         SOPartFreq  \
# 0                              NaN
# 1  A few times per month or weekly
#
#                                               SOJobs  \
# 0  No, I didn't know that Stack Overflow had a jo...
# 1  No, I knew that Stack Overflow had a job board...
#
#                               EntTeams         SOComm  \
# 0  No, and I don't know what those are        Neutral
# 1  No, and I don't know what those are  Yes, somewhat
#
#                              WelcomeChange  \
# 0  Just as welcome now as I felt last year
# 1  Just as welcome now as I felt last year
#
#                                         SONewContent   Age Gender Trans  \
# 0  Tech articles written by other developers;Indu...  14.0    Man    No
# 1  Tech articles written by other developers;Indu...  19.0    Man    No
#
#                  Sexuality Ethnicity Dependents           SurveyLength  \
# 0  Straight / Heterosexual       NaN         No  Appropriate in length
# 1  Straight / Heterosexual       NaN         No  Appropriate in length
#
#                    SurveyEase
# 0  Neither easy nor difficult
# 1  Neither easy nor difficult

# %%
#reproduce the following
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83439 entries, 0 to 83438
# Data columns (total 48 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ResponseId                    83439 non-null  int64
#  1   MainBranch                    83439 non-null  object
#  2   Employment                    83323 non-null  object
#  3   Country                       83439 non-null  object
#  4   US_State                      14920 non-null  object
#  5   UK_Country                    4418 non-null   object
#  6   EdLevel                       83126 non-null  object
#  7   Age1stCode                    83243 non-null  object
#  8   LearnCode                     82963 non-null  object
#  9   YearsCode                     81641 non-null  object
#  10  YearsCodePro                  61216 non-null  object
#  11  DevType                       66484 non-null  object
#  12  OrgSize                       60726 non-null  object
#  13  Currency                      61080 non-null  object
#  14  CompTotal                     47183 non-null  float64
#  15  CompFreq                      52150 non-null  object
#  16  LanguageHaveWorkedWith        82357 non-null  object
#  17  LanguageWantToWorkWith        76821 non-null  object
#  18  DatabaseHaveWorkedWith        69546 non-null  object
#  19  DatabaseWantToWorkWith        58299 non-null  object
#  20  PlatformHaveWorkedWith        52135 non-null  object
#  21  PlatformWantToWorkWith        41619 non-null  object
#  22  WebframeHaveWorkedWith        61707 non-null  object
#  23  WebframeWantToWorkWith        52095 non-null  object
#  24  MiscTechHaveWorkedWith        47055 non-null  object
#  25  MiscTechWantToWorkWith        38021 non-null  object
#  26  ToolsTechHaveWorkedWith       72537 non-null  object
#  27  ToolsTechWantToWorkWith       65480 non-null  object
#  28  NEWCollabToolsHaveWorkedWith  81234 non-null  object
#  29  NEWCollabToolsWantToWorkWith  73022 non-null  object
#  30  OpSys                         83294 non-null  object
#  31  NEWStuck                      83052 non-null  object
#  32  NEWSOSites                    83171 non-null  object
#  33  SOVisitFreq                   82413 non-null  object
#  34  SOAccount                     82525 non-null  object
#  35  SOPartFreq                    67553 non-null  object
#  36  SOComm                        82319 non-null  object
#  37  NEWOtherComms                 82828 non-null  object
#  38  Age                           82407 non-null  object
#  39  Gender                        82286 non-null  object
#  40  Trans                         80678 non-null  object
#  41  Sexuality                     73366 non-null  object
#  42  Ethnicity                     79464 non-null  object
#  43  Accessibility                 77603 non-null  object
#  44  MentalHealth                  76920 non-null  object
#  45  SurveyLength                  81711 non-null  object
#  46  SurveyEase                    81948 non-null  object
#  47  ConvertedCompYearly           46844 non-null  float64
# dtypes: float64(2), int64(1), object(45)
# memory usage: 30.6+ MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
#  14  Age1stCode              87634 non-null  object
#  15  YearsCodePro            74331 non-null  object
#  16  CareerSat               72847 non-null  object
#  17  JobSat                  70988 non-null  object
#  18  MgrIdiot                61159 non-null  object
#  19  MgrMoney                61157 non-null  object
#  20  MgrWant                 61232 non-null  object
#  21  JobSeek                 80555 non-null  object
#  22  LastHireDate            79854 non-null  object
#  23  LastInt                 67155 non-null  object
#  24  FizzBuzz                71344 non-null  object
#  25  JobFactors              79371 non-null  object
#  26  ResumeUpdate            77877 non-null  object
#  27  CurrencySymbol          71392 non-null  object
#  28  CurrencyDesc            71392 non-null  object
#  29  CompTotal               55945 non-null  float64
#  30  CompFreq                63268 non-null  object
#  31  ConvertedComp           55823 non-null  float64
#  32  WorkWeekHrs             64503 non-null  float64
#  33  WorkPlan                68914 non-null  object
#  34  WorkChallenge           68141 non-null  object
#  35  WorkRemote              70284 non-null  object
#  36  WorkLoc                 70055 non-null  object
#  37  ImpSyn                  71779 non-null  object
#  38  CodeRev                 70390 non-null  object
#  39  CodeRevHrs              49790 non-null  float64
#  40  UnitTests               62668 non-null  object
#  41  PurchaseHow             61108 non-null  object
#  42  PurchaseWhat            62029 non-null  object
#  43  LanguageWorkedWith      87569 non-null  object
#  44  LanguageDesireNextYear  84088 non-null  object
#  45  DatabaseWorkedWith      76026 non-null  object
#  46  DatabaseDesireNextYear  69147 non-null  object
#  47  PlatformWorkedWith      80714 non-null  object
#  48  PlatformDesireNextYear  77443 non-null  object
#  49  WebFrameWorkedWith      65022 non-null  object
#  50  WebFrameDesireNextYear  62944 non-null  object
#  51  MiscTechWorkedWith      59586 non-null  object
#  52  MiscTechDesireNextYear  64511 non-null  object
#  53  DevEnviron              87317 non-null  object
#  54  OpSys                   87851 non-null  object
#  55  Containers              85366 non-null  object
#  56  BlockchainOrg           48175 non-null  object
#  57  BlockchainIs            60165 non-null  object
#  58  BetterLife              86269 non-null  object
#  59  ITperson                87141 non-null  object
#  60  OffOn                   86663 non-null  object
#  61  SocialMedia             84437 non-null  object
#  62  Extraversion            87305 non-null  object
#  63  ScreenName              80486 non-null  object
#  64  SOVisit1st              83877 non-null  object
#  65  SOVisitFreq             88263 non-null  object
#  66  SOVisitTo               88086 non-null  object
#  67  SOFindAnswer            87816 non-null  object
#  68  SOTimeSaved             86344 non-null  object
#  69  SOHowMuchTime           68378 non-null  object
#  70  SOAccount               87828 non-null  object
#  71  SOPartFreq              74692 non-null  object
#  72  SOJobs                  88066 non-null  object
#  73  EntTeams                87841 non-null  object
#  74  SOComm                  88131 non-null  object
#  75  WelcomeChange           85855 non-null  object
#  76  SONewContent            69560 non-null  object
#  77  Age                     79210 non-null  float64
#  78  Gender                  85406 non-null  object
#  79  Trans                   83607 non-null  object
#  80  Sexuality               76147 non-null  object
#  81  Ethnicity               76668 non-null  object
#  82  Dependents              83059 non-null  object
#  83  SurveyLength            86984 non-null  object
#  84  SurveyEase              87081 non-null  object
# dtypes: float64(5), int64(1), object(79)
# memory usage: 57.6+ MB

# %%
# We want to convert the age entries onto float/int by grabbing the first part
# of the sting. Hint( build a function called age_convert)

# %%
def age_convert(x):
    return int(x)

# %%
#Use lambda funtion to apply the age_convert funtion to the entire age column
df['Age'] = df['Age'].apply(lambda x: int(x) if pd.notnull(x) else 0)

# %%
df['Age']
# Out:
# 0        14
# 1        19
# 2        28
# 3        22
# 4        30
#          ..
# 88878     0
# 88879     0
# 88880     0
# 88881     0
# 88882    18
# Name: Age, Length: 88883, dtype: int64

# %%
# Notice that the age type is still an object type. Convert it to numberic
df['Age'] = pd.to_numeric(df['Age'], downcast='integer')

# %%
df['Age'].dtype
# Out:
# dtype('int8')

# %%
# Out:
# dtype('float64')

# %%
# Describe the dataframe after converting the age column to numeric one
# Out:
#          ResponseId     CompTotal           Age  ConvertedCompYearly
# count  83439.000000  4.718300e+04  76035.000000         4.684400e+04
# mean   41720.000000  2.119407e+69     27.221201         1.184262e+05
# std    24086.908893  4.603702e+71      8.881559         5.272944e+05
# min        1.000000  0.000000e+00     18.000000         1.000000e+00
# 25%    20860.500000  1.600000e+04     18.000000         2.702500e+04
# 50%    41720.000000  6.700000e+04     25.000000         5.621100e+04
# 75%    62579.500000  1.400000e+05     35.000000         1.000000e+05
# max    83439.000000  1.000000e+74     55.000000         4.524131e+07

# %%
agg_df = df[["Respondent", "CompTotal", "Age", "ConvertedComp"]].agg(aggregations)
agg_df
# Out:
#             Respondent     CompTotal           Age  ConvertedComp
# count     88883.000000  5.594500e+04  88883.000000   5.582300e+04
# mean      44442.000000  5.519014e+11     27.034900   1.271107e+05
# std       25658.456325  7.331926e+13     12.819143   2.841523e+05
# min           1.000000  0.000000e+00      0.000000   0.000000e+00
# <lambda>  22221.500000  2.000000e+04     22.000000   2.577750e+04
# median    44442.000000  6.200000e+04     27.000000   5.728700e+04
# <lambda>  66662.500000  1.200000e+05     34.000000   1.000000e+05
# max       88883.000000  1.000000e+16     99.000000   2.000000e+06

# %%
# Drop the following columns: 'US_State','UK_Country' and'Age'
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# 1                                     Student, full-time
# 2                                     Student, full-time
# 3                                     Employed full-time
# 4      Independent contractor, freelancer, or self-em...
# ...                                                  ...
# 83434                                 Employed full-time
# 83435  Independent contractor, freelancer, or self-em...
# 83436                                 Employed full-time
# 83437                                 Employed full-time
# 83438                                 Employed full-time
#
#                                                  Country  \
# 0                                               Slovakia
# 1                                            Netherlands
# 2                                     Russian Federation
# 3                                                Austria
# 4      United Kingdom of Great Britain and Northern I...
# ...                                                  ...
# 83434                           United States of America
# 83435                                              Benin
# 83436                           United States of America
# 83437                                             Canada
# 83438                                             Brazil
#
#                                                  EdLevel     Age1stCode  \
# 0      Secondary school (e.g. American high school, G...  18 - 24 years
# 1           Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 2           Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 3        Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  11 - 17 years
# 4        Master’s degree (M.A., M.S., M.Eng., MBA, etc.)   5 - 10 years
# ...                                                  ...            ...
# 83434       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 83435       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 83436  Secondary school (e.g. American high school, G...  11 - 17 years
# 83437       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 83438                 Professional degree (JD, MD, etc.)  11 - 17 years
#
#                                                LearnCode YearsCode  \
# 0      Coding Bootcamp;Other online resources (ex: vi...       NaN
# 1      Other online resources (ex: videos, blogs, etc...         7
# 2      Other online resources (ex: videos, blogs, etc...       NaN
# 3                                                    NaN       NaN
# 4                                Friend or family member        17
# ...                                                  ...       ...
# 83434  Other online resources (ex: videos, blogs, etc...         6
# 83435  Other online resources (ex: videos, blogs, etc...         4
# 83436                                             School        10
# 83437  Online Courses or Certification;Books / Physic...         5
# 83438                                             School        14
#
#       YearsCodePro                                            DevType  \
# 0              NaN                                  Developer, mobile
# 1              NaN                                                NaN
# 2              NaN                                                NaN
# 3              NaN                               Developer, front-end
# 4               10  Developer, desktop or enterprise applications;...
# ...            ...                                                ...
# 83434            5                                Developer, back-end
# 83435            2                              Developer, full-stack
# 83436            4  Data scientist or machine learning specialist;...
# 83437            3                                Developer, back-end
# 83438            4  Developer, front-end;Developer, full-stack;Dev...
#
#                                                  OrgSize  \
# 0                                     20 to 99 employees
# 1                                                    NaN
# 2                                                    NaN
# 3                                   100 to 499 employees
# 4      Just me - I am a freelancer, sole proprietor, ...
# ...                                                  ...
# 83434                                 20 to 99 employees
# 83435  Just me - I am a freelancer, sole proprietor, ...
# 83436                           10,000 or more employees
# 83437                                 20 to 99 employees
# 83438                                       I don’t know
#
#                           Currency  CompTotal CompFreq  \
# 0                EUR European Euro     4800.0  Monthly
# 1                              NaN        NaN      NaN
# 2                              NaN        NaN      NaN
# 3                EUR European Euro        NaN  Monthly
# 4              GBP\tPound sterling        NaN      NaN
# ...                            ...        ...      ...
# 83434    USD\tUnited States dollar   160500.0   Yearly
# 83435  XOF\tWest African CFA franc   200000.0  Monthly
# 83436    USD\tUnited States dollar     1800.0   Weekly
# 83437         CAD\tCanadian dollar    90000.0  Monthly
# 83438          BRL\tBrazilian real     7700.0  Monthly
#
#                               LanguageHaveWorkedWith  \
# 0      C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 1                                  JavaScript;Python
# 2                           Assembly;C;Python;R;Rust
# 3                              JavaScript;TypeScript
# 4                     Bash/Shell;HTML/CSS;Python;SQL
# ...                                              ...
# 83434                             Clojure;Kotlin;SQL
# 83435                                            NaN
# 83436                             Groovy;Java;Python
# 83437           Bash/Shell;JavaScript;Node.js;Python
# 83438         Delphi;Elixir;HTML/CSS;Java;JavaScript
#
#                                   LanguageWantToWorkWith  \
# 0                                                  Swift
# 1                                                    NaN
# 2                                      Julia;Python;Rust
# 3                                  JavaScript;TypeScript
# 4                         Bash/Shell;HTML/CSS;Python;SQL
# ...                                                  ...
# 83434                                            Clojure
# 83435                                                NaN
# 83436                                        Java;Python
# 83437                                            Go;Rust
# 83438  Elixir;HTML/CSS;Java;JavaScript;Node.js;PHP;SQ...
#
#                                  DatabaseHaveWorkedWith  \
# 0                                     PostgreSQL;SQLite
# 1                                            PostgreSQL
# 2                                                SQLite
# 3                                                   NaN
# 4                        Elasticsearch;PostgreSQL;Redis
# ...                                                 ...
# 83434                                     Oracle;SQLite
# 83435    Firebase;MariaDB;MySQL;PostgreSQL;Redis;SQLite
# 83436   DynamoDB;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83437  Cassandra;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83438                                 Oracle;PostgreSQL
#
#                                   DatabaseWantToWorkWith  \
# 0                                                 SQLite
# 1                                                    NaN
# 2                                                 SQLite
# 3                                                    NaN
# 4               Cassandra;Elasticsearch;PostgreSQL;Redis
# ...                                                  ...
# 83434                                             SQLite
# 83435  Firebase;MariaDB;MongoDB;MySQL;PostgreSQL;Redi...
# 83436                                     DynamoDB;Redis
# 83437                                                NaN
# 83438  Elasticsearch;MongoDB;MySQL;Oracle;PostgreSQL;...
#
#           PlatformHaveWorkedWith PlatformWantToWorkWith  \
# 0                            NaN                    NaN
# 1                            NaN                    NaN
# 2                         Heroku                    NaN
# 3                            NaN                    NaN
# 4                            NaN                    NaN
# ...                          ...                    ...
# 83434                        AWS                    AWS
# 83435                        NaN                    NaN
# 83436  AWS;Google Cloud Platform                    AWS
# 83437                     Heroku       AWS;DigitalOcean
# 83438            Microsoft Azure                    AWS
#
#                              WebframeHaveWorkedWith  \
# 0                                   Laravel;Symfony
# 1                              Angular;Flask;Vue.js
# 2                                             Flask
# 3                                    Angular;jQuery
# 4                                             Flask
# ...                                             ...
# 83434                                           NaN
# 83435  Django;jQuery;Laravel;React.js;Ruby on Rails
# 83436                                 FastAPI;Flask
# 83437                 Django;Express;Flask;React.js
# 83438                                Angular;Spring
#
#                                   WebframeWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                  Flask
# 3                                         Angular;jQuery
# 4                                                  Flask
# ...                                                  ...
# 83434                                                NaN
# 83435  Django;Express;jQuery;Laravel;React.js;Ruby on...
# 83436                                      FastAPI;Flask
# 83437                                                NaN
# 83438                     Express;Laravel;Spring;Symfony
#
#                       MiscTechHaveWorkedWith  \
# 0                                        NaN
# 1                                    Cordova
# 2      NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                        NaN
# 4           Apache Spark;Hadoop;NumPy;Pandas
# ...                                      ...
# 83434                                    NaN
# 83435                             Flutter;Qt
# 83436              Hadoop;Keras;NumPy;Pandas
# 83437  NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                    NaN
#
#                                   MiscTechWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2            Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                                    NaN
# 4                                    Hadoop;NumPy;Pandas
# ...                                                  ...
# 83434                                                NaN
# 83435                                                NaN
# 83436  Apache Spark;Hadoop;Keras;NumPy;Pandas;TensorFlow
# 83437              NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                                NaN
#
#             ToolsTechHaveWorkedWith          ToolsTechWantToWorkWith  \
# 0                               NaN                              NaN
# 1                   Docker;Git;Yarn                              Git
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4        Docker;Git;Kubernetes;Yarn       Docker;Git;Kubernetes;Yarn
# ...                             ...                              ...
# 83434                    Docker;Git                   Git;Kubernetes
# 83435    Git;Unity 3D;Unreal Engine            Docker;Git;Kubernetes
# 83436  Ansible;Docker;Git;Terraform  Docker;Git;Kubernetes;Terraform
# 83437  Ansible;Docker;Git;Terraform             Kubernetes;Terraform
# 83438                    Docker;Git            Docker;Git;Kubernetes
#
#                             NEWCollabToolsHaveWorkedWith  \
# 0                                         PHPStorm;Xcode
# 1              Android Studio;IntelliJ;Notepad++;PyCharm
# 2      IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 3                                                    NaN
# 4             Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
# ...                                                  ...
# 83434       IntelliJ;Sublime Text;Vim;Visual Studio Code
# 83435  Android Studio;Eclipse;Emacs;IntelliJ;NetBeans...
# 83436  Android Studio;Eclipse;IntelliJ;IPython/Jupyte...
# 83437                               PyCharm;Sublime Text
# 83438                        IntelliJ;Visual Studio Code
#
#                             NEWCollabToolsWantToWorkWith        OpSys  \
# 0                                             Atom;Xcode        MacOS
# 1                                                    NaN      Windows
# 2      IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 3                                                    NaN      Windows
# 4      Atom;IPython/Jupyter;Notepad++;PyCharm;Vim;Vis...  Linux-based
# ...                                                  ...          ...
# 83434                                   Sublime Text;Vim        MacOS
# 83435  Emacs;IntelliJ;PHPStorm;PyCharm;RStudio;Sublim...  Linux-based
# 83436             IntelliJ;IPython/Jupyter;Notepad++;Vim      Windows
# 83437                                                NaN        MacOS
# 83438               IntelliJ;PHPStorm;Visual Studio Code  Linux-based
#
#                                                 NEWStuck  \
# 0      Call a coworker or friend;Visit Stack Overflow...
# 1                         Visit Stack Overflow;Google it
# 2      Visit Stack Overflow;Google it;Watch help / tu...
# 3      Call a coworker or friend;Visit Stack Overflow...
# 4      Visit Stack Overflow;Go for a walk or other ph...
# ...                                                  ...
# 83434                Call a coworker or friend;Google it
# 83435  Call a coworker or friend;Visit Stack Overflow...
# 83436  Call a coworker or friend;Visit Stack Overflow...
# 83437  Call a coworker or friend;Visit Stack Overflow...
# 83438  Call a coworker or friend;Visit Stack Overflow...
#
#                                               NEWSOSites  \
# 0                                         Stack Overflow
# 1                                         Stack Overflow
# 2                          Stack Overflow;Stack Exchange
# 3                                         Stack Overflow
# 4                          Stack Overflow;Stack Exchange
# ...                                                  ...
# 83434                      Stack Overflow;Stack Exchange
# 83435                      Stack Overflow;Stack Exchange
# 83436                      Stack Overflow;Stack Exchange
# 83437                                     Stack Overflow
# 83438  Stack Overflow;Stack Exchange;Stack Overflow f...
#
#                            SOVisitFreq SOAccount  \
# 0               Multiple times per day       Yes
# 1                Daily or almost daily       Yes
# 2               Multiple times per day       Yes
# 3                Daily or almost daily       Yes
# 4                Daily or almost daily       Yes
# ...                                ...       ...
# 83434             A few times per week        No
# 83435           Multiple times per day       Yes
# 83436             A few times per week       Yes
# 83437  A few times per month or weekly       Yes
# 83438             A few times per week       Yes
#
#                                               SOPartFreq           SOComm  \
# 0                        A few times per month or weekly  Yes, definitely
# 1                                  Daily or almost daily  Yes, definitely
# 2                                 Multiple times per day  Yes, definitely
# 3                                  Daily or almost daily          Neutral
# 4                                   A few times per week    Yes, somewhat
# ...                                                  ...              ...
# 83434                                                NaN   No, not at all
# 83435  I have never participated in Q&A on Stack Over...    Yes, somewhat
# 83436  I have never participated in Q&A on Stack Over...   No, not really
# 83437                Less than once per month or monthly   No, not really
# 83438                               A few times per week    Yes, somewhat
#
#       NEWOtherComms Gender Trans                Sexuality  \
# 0                No    Man    No  Straight / Heterosexual
# 1                No    Man    No  Straight / Heterosexual
# 2               Yes    Man    No        Prefer not to say
# 3                No    Man    No  Straight / Heterosexual
# 4                No    Man    No                      NaN
# ...             ...    ...   ...                      ...
# 83434            No    Man    No  Straight / Heterosexual
# 83435            No    Man    No  Straight / Heterosexual
# 83436            No    Man    No                      NaN
# 83437            No    Man    No  Straight / Heterosexual
# 83438            No    Man    No  Straight / Heterosexual
#
#                           Ethnicity                Accessibility  \
# 0      White or of European descent            None of the above
# 1      White or of European descent            None of the above
# 2                 Prefer not to say            None of the above
# 3      White or of European descent  I am deaf / hard of hearing
# 4      White or of European descent            None of the above
# ...                             ...                          ...
# 83434  White or of European descent            None of the above
# 83435   Black or of African descent            None of the above
# 83436  White or of European descent            None of the above
# 83437  White or of European descent            None of the above
# 83438        Hispanic or Latino/a/x            None of the above
#
#                                             MentalHealth  \
# 0                                      None of the above
# 1                                      None of the above
# 2                                      None of the above
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 83434  I have a concentration and/or memory disorder ...
# 83435                                  None of the above
# 83436                                  None of the above
# 83437  I have a mood or emotional disorder (e.g. depr...
# 83438                                  None of the above
#
#                 SurveyLength                  SurveyEase  ConvertedCompYearly
# 0      Appropriate in length                        Easy              62268.0
# 1      Appropriate in length                        Easy                  NaN
# 2      Appropriate in length                        Easy                  NaN
# 3      Appropriate in length  Neither easy nor difficult                  NaN
# 4      Appropriate in length                        Easy                  NaN
# ...                      ...                         ...                  ...
# 83434  Appropriate in length                        Easy             160500.0
# 83435  Appropriate in length                        Easy               3960.0
# 83436  Appropriate in length  Neither easy nor difficult              90000.0
# 83437  Appropriate in length  Neither easy nor difficult             816816.0
# 83438  Appropriate in length                        Easy              21168.0
#
# [83439 rows x 45 columns]

# %%
df.drop(['US_State', 'UK_Country', 'Age'], axis=1)
df.info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 df.drop(['US_State', 'UK_Country', 'Age'], axis=1)
#       2 df.info()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:6699, in Index.drop(self, labels, errors)
#    6697 if mask.any():
#    6698     if errors != "ignore":
# -> 6699         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700     indexer = indexer[~mask]
#    6701 return self.delete(indexer)
#
# KeyError: "['US_State', 'UK_Country'] not found in axis"

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83439 entries, 0 to 83438
# Data columns (total 48 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ResponseId                    83439 non-null  int64
#  1   MainBranch                    83439 non-null  object
#  2   Employment                    83323 non-null  object
#  3   Country                       83439 non-null  object
#  4   US_State                      14920 non-null  object
#  5   UK_Country                    4418 non-null   object
#  6   EdLevel                       83126 non-null  object
#  7   Age1stCode                    83243 non-null  object
#  8   LearnCode                     82963 non-null  object
#  9   YearsCode                     81641 non-null  object
#  10  YearsCodePro                  61216 non-null  object
#  11  DevType                       66484 non-null  object
#  12  OrgSize                       60726 non-null  object
#  13  Currency                      61080 non-null  object
#  14  CompTotal                     47183 non-null  float64
#  15  CompFreq                      52150 non-null  object
#  16  LanguageHaveWorkedWith        82357 non-null  object
#  17  LanguageWantToWorkWith        76821 non-null  object
#  18  DatabaseHaveWorkedWith        69546 non-null  object
#  19  DatabaseWantToWorkWith        58299 non-null  object
#  20  PlatformHaveWorkedWith        52135 non-null  object
#  21  PlatformWantToWorkWith        41619 non-null  object
#  22  WebframeHaveWorkedWith        61707 non-null  object
#  23  WebframeWantToWorkWith        52095 non-null  object
#  24  MiscTechHaveWorkedWith        47055 non-null  object
#  25  MiscTechWantToWorkWith        38021 non-null  object
#  26  ToolsTechHaveWorkedWith       72537 non-null  object
#  27  ToolsTechWantToWorkWith       65480 non-null  object
#  28  NEWCollabToolsHaveWorkedWith  81234 non-null  object
#  29  NEWCollabToolsWantToWorkWith  73022 non-null  object
#  30  OpSys                         83294 non-null  object
#  31  NEWStuck                      83052 non-null  object
#  32  NEWSOSites                    83171 non-null  object
#  33  SOVisitFreq                   82413 non-null  object
#  34  SOAccount                     82525 non-null  object
#  35  SOPartFreq                    67553 non-null  object
#  36  SOComm                        82319 non-null  object
#  37  NEWOtherComms                 82828 non-null  object
#  38  Age                           76035 non-null  float64
#  39  Gender                        82286 non-null  object
#  40  Trans                         80678 non-null  object
#  41  Sexuality                     73366 non-null  object
#  42  Ethnicity                     79464 non-null  object
#  43  Accessibility                 77603 non-null  object
#  44  MentalHealth                  76920 non-null  object
#  45  SurveyLength                  81711 non-null  object
#  46  SurveyEase                    81948 non-null  object
#  47  ConvertedCompYearly           46844 non-null  float64
# dtypes: float64(3), int64(1), object(44)
# memory usage: 30.6+ MB

# %%
# Group your dataframe by country and check the number people in the U.S. responded to the  survey

#to see the all the rows of the value_counts()

# %%
df_usa = df['Country'].value_counts()
df_usa
# Out:
# Country
# United States        20949
# India                 9061
# Germany               5866
# United Kingdom        5737
# Canada                3395
#                      ...
# Tonga                    1
# Timor-Leste              1
# North Korea              1
# Brunei Darussalam        1
# Chad                     1
# Name: count, Length: 179, dtype: int64

# %%
# Out:
# Country
# United States of America                                15288
# India                                                   10511
# Germany                                                  5625
# United Kingdom of Great Britain and Northern Ireland     4475
# Canada                                                   3012
# France                                                   2708
# Brazil                                                   2254
# Poland                                                   1805
# Netherlands                                              1772
# Italy                                                    1666
# Australia                                                1646
# Spain                                                    1485
# Russian Federation                                       1474
# Sweden                                                   1196
# China                                                    1055
# Turkey                                                   1054
# Switzerland                                               922
# Israel                                                    913
# Iran, Islamic Republic of...                              900
# Pakistan                                                  838
# Austria                                                   808
# Czech Republic                                            792
# Ukraine                                                   770
# Bangladesh                                                704
# Belgium                                                   697
# Mexico                                                    695
# Romania                                                   650
# Indonesia                                                 632
# Greece                                                    603
# Norway                                                    602
# Denmark                                                   599
# Argentina                                                 587
# South Africa                                              571
# Portugal                                                  530
# Finland                                                   528
# New Zealand                                               522
# Egypt                                                     521
# Hungary                                                   478
# Japan                                                     429
# Nigeria                                                   409
# Bulgaria                                                  402
# Sri Lanka                                                 396
# Viet Nam                                                  386
# Ireland                                                   386
# Philippines                                               382
# Colombia                                                  381
# Singapore                                                 339
# Nepal                                                     337
# Malaysia                                                  333
# Serbia                                                    310
# Taiwan                                                    302
# Kenya                                                     263
# Slovakia                                                  252
# Croatia                                                   250
# Slovenia                                                  235
# Chile                                                     230
# Lithuania                                                 208
# Morocco                                                   204
# Hong Kong (S.A.R.)                                        198
# South Korea                                               189
# Thailand                                                  184
# United Arab Emirates                                      182
# Belarus                                                   165
# Georgia                                                   161
# Tunisia                                                   150
# Peru                                                      147
# Uruguay                                                   144
# Saudi Arabia                                              137
# Bosnia and Herzegovina                                    130
# Estonia                                                   130
# Lebanon                                                   113
# Latvia                                                    107
# Dominican Republic                                        104
# Venezuela, Bolivarian Republic of...                      104
# Ecuador                                                   103
# Armenia                                                    92
# Ghana                                                      91
# Costa Rica                                                 77
# Iraq                                                       76
# Albania                                                    73
# Jordan                                                     72
# Ethiopia                                                   69
# Uzbekistan                                                 68
# Afghanistan                                                65
# Kazakhstan                                                 65
# Azerbaijan                                                 64
# Uganda                                                     63
# Guatemala                                                  58
# Cyprus                                                     56
# Myanmar                                                    55
# Republic of Moldova                                        55
# Republic of Korea                                          54
# Nomadic                                                    54
# The former Yugoslav Republic of Macedonia                  54
# Luxembourg                                                 51
# Syrian Arab Republic                                       51
# Bolivia                                                    48
# Paraguay                                                   47
# Algeria                                                    46
# Kosovo                                                     45
# United Republic of Tanzania                                43
# Iceland                                                    43
# Malta                                                      42
# Cameroon                                                   38
# Zimbabwe                                                   36
# Cambodia                                                   35
# Rwanda                                                     34
# Cuba                                                       34
# El Salvador                                                32
# Panama                                                     31
# Mauritius                                                  31
# Qatar                                                      29
# Kuwait                                                     29
# Bahrain                                                    28
# Senegal                                                    28
# Angola                                                     27
# Sudan                                                      27
# Palestine                                                  25
# Honduras                                                   24
# Zambia                                                     22
# Mongolia                                                   21
# Kyrgyzstan                                                 21
# Jamaica                                                    20
# Trinidad and Tobago                                        20
# Yemen                                                      20
# Oman                                                       20
# Nicaragua                                                  18
# Madagascar                                                 18
# Montenegro                                                 17
# Côte d'Ivoire                                              17
# Maldives                                                   16
# Benin                                                      15
# Turkmenistan                                               13
# Mozambique                                                 12
# Namibia                                                    12
# Andorra                                                    12
# Barbados                                                   12
# Congo, Republic of the...                                  12
# Libyan Arab Jamahiriya                                     11
# Malawi                                                     11
# Democratic Republic of the Congo                           10
# Swaziland                                                  10
# Tajikistan                                                  9
# Bahamas                                                     7
# Togo                                                        7
# Somalia                                                     7
# Guyana                                                      7
# Botswana                                                    6
# Cape Verde                                                  6
# North Korea                                                 6
# Haiti                                                       5
# Belize                                                      5
# Isle of Man                                                 5
# Mauritania                                                  5
# Bhutan                                                      5
# Suriname                                                    5
# Burundi                                                     5
# Fiji                                                        4
# Burkina Faso                                                4
# Lesotho                                                     4
# Lao People's Democratic Republic                            4
# Niger                                                       3
# Central African Republic                                    3
# Liberia                                                     3
# Saint Lucia                                                 3
# Djibouti                                                    3
# San Marino                                                  2
# Guinea                                                      2
# Sierra Leone                                                2
# Micronesia, Federated States of...                          2
# Chad                                                        2
# Gambia                                                      2
# Monaco                                                      2
# Mali                                                        2
# Brunei Darussalam                                           1
# Liechtenstein                                               1
# Saint Kitts and Nevis                                       1
# Dominica                                                    1
# Saint Vincent and the Grenadines                            1
# Tuvalu                                                      1
# Papua New Guinea                                            1
# Name: count, dtype: int64

# %%
# What is the median salary of the developer in 'United States of America',
#'United Kingdom of Great Britain and Northern Ireland',
#'Canada','Germany','India','France'?

# %%
df_median_salary_by_country = df.groupby('Country')['ConvertedComp'].median()
country_list = ['United States','United Kingdom','Canada','Germany','India','France']
country_list.sort()
df_median_salary_by_country[country_list]
# Out:
# Country
# Canada             68705.0
# France             46752.0
# Germany            63016.0
# India              10080.0
# United Kingdom     68041.0
# United States     110000.0
# Name: ConvertedComp, dtype: float64

# %%
# Out:
# Country
# Canada                                                   75631.0
# France                                                   48936.0
# Germany                                                  64859.0
# India                                                    14748.0
# United Kingdom of Great Britain and Northern Ireland     74970.0
# United States of America                                125000.0
# Name: ConvertedCompYearly, dtype: float64

# %%
df_salary_2 = df.groupby('Country')['ConvertedComp'].agg(['median', 'mean'])
df_salary_2.loc[country_list]
# Out:
#                   median           mean
# Country
# Canada           68705.0  134018.564909
# France           46752.0   81214.779722
# Germany          63016.0  109256.884066
# India            10080.0   28057.664916
# United Kingdom   68041.0  166182.499504
# United States   110000.0  249546.254589

# %%
#Mean and Median
# Out:
#                                                       median           mean
# Country
# Canada                                               75631.0  135732.563006
# France                                               48936.0   90213.514670
# Germany                                              64859.0  103014.516754
# India                                                14748.0   42522.583464
# United Kingdom of Great Britain and Northern Ir...   74970.0  141688.554608
# United States of America                            125000.0  262993.898480

# %%
# How many people in the US work with Python?
# Out:
# (15288, 48)

# %%
pd.set_option('display.max_rows', 10)

# %%
df['PythonUser'] = df['LanguageWorkedWith'].str.contains('Python')
df_usa_python = df[(df['Country'] == 'United States') & (df['PythonUser'] == True)]
df_usa_python
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 3               4  I am a developer by profession       No
# 21             22  I am a developer by profession      Yes
# 22             23  I am a developer by profession      Yes
# 25             26  I am a developer by profession      Yes
# 31             32  I am a developer by profession       No
# ...           ...                             ...      ...
# 88758       67206                             NaN      Yes
# 88764       68208                             NaN      Yes
# 88786       72325                             NaN      Yes
# 88818       78292                             NaN       No
# 88844       83397                             NaN      Yes
#
#                       OpenSourcer  \
# 3                           Never
# 21        Less than once per year
# 22        Less than once per year
# 25        Less than once per year
# 31                          Never
# ...                           ...
# 88758  Once a month or more often
# 88764     Less than once per year
# 88786  Once a month or more often
# 88818  Once a month or more often
# 88844     Less than once per year
#
#                                               OpenSource  \
# 3      The quality of OSS and closed source software ...
# 21     OSS is, on average, of HIGHER quality than pro...
# 22     The quality of OSS and closed source software ...
# 25     The quality of OSS and closed source software ...
# 31     The quality of OSS and closed source software ...
# ...                                                  ...
# 88758  The quality of OSS and closed source software ...
# 88764  The quality of OSS and closed source software ...
# 88786  OSS is, on average, of HIGHER quality than pro...
# 88818  OSS is, on average, of HIGHER quality than pro...
# 88844                                                NaN
#
#                                               Employment        Country  \
# 3                                     Employed full-time  United States
# 21                                    Employed full-time  United States
# 22                                    Employed full-time  United States
# 25                                    Employed full-time  United States
# 31                                    Employed full-time  United States
# ...                                                  ...            ...
# 88758             Not employed, and not looking for work  United States
# 88764                                                NaN  United States
# 88786  Independent contractor, freelancer, or self-em...  United States
# 88818  Independent contractor, freelancer, or self-em...  United States
# 88844                 Not employed, but looking for work  United States
#
#       Student                                            EdLevel  \
# 3          No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 21         No  Some college/university study without earning ...
# 22         No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 25         No  Some college/university study without earning ...
# 31         No                                   Associate degree
# ...       ...                                                ...
# 88758      No  Secondary school (e.g. American high school, G...
# 88764      No  Some college/university study without earning ...
# 88786      No  Secondary school (e.g. American high school, G...
# 88818      No          Other doctoral degree (Ph.D, Ed.D., etc.)
# 88844      No           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                           UndergradMajor  ...  \
# 3      Computer science, computer engineering, or sof...  ...
# 21                                                   NaN  ...
# 22     Information systems, information technology, o...  ...
# 25     Computer science, computer engineering, or sof...  ...
# 31     Information systems, information technology, o...  ...
# ...                                                  ...  ...
# 88758                                                NaN  ...
# 88764                           I never declared a major  ...
# 88786                                                NaN  ...
# 88818  A health science (ex. nursing, pharmacy, radio...  ...
# 88844  Computer science, computer engineering, or sof...  ...
#
#                                             SONewContent   Age Gender Trans  \
# 3      Tech articles written by other developers;Indu...  22.0    Man    No
# 21     Tech articles written by other developers;Indu...  47.0    Man    No
# 22     Tech articles written by other developers;Tech...  22.0    Man    No
# 25                                                   NaN  34.0    Man    No
# 31     Tech articles written by other developers;Indu...  21.0    Man    No
# ...                                                  ...   ...    ...   ...
# 88758  Tech articles written by other developers;Indu...  14.0    Man    No
# 88764                                                NaN   NaN    Man    No
# 88786  Tech meetups or events in your area;Courses on...  15.0    Man    No
# 88818                                                NaN  60.0    Man    No
# 88844                                                NaN  27.0  Woman    No
#
#                      Sexuality                     Ethnicity Dependents  \
# 3      Straight / Heterosexual  White or of European descent         No
# 21     Straight / Heterosexual  White or of European descent        Yes
# 22     Straight / Heterosexual   Black or of African descent         No
# 25              Gay or Lesbian                           NaN         No
# 31     Straight / Heterosexual  White or of European descent         No
# ...                        ...                           ...        ...
# 88758  Straight / Heterosexual                   South Asian         No
# 88764  Straight / Heterosexual  White or of European descent        Yes
# 88786                      NaN  White or of European descent         No
# 88818  Straight / Heterosexual  White or of European descent        Yes
# 88844                 Bisexual  White or of European descent         No
#
#                 SurveyLength                  SurveyEase PythonUser
# 3      Appropriate in length                        Easy       True
# 21     Appropriate in length                        Easy       True
# 22     Appropriate in length                        Easy       True
# 25     Appropriate in length                        Easy       True
# 31     Appropriate in length  Neither easy nor difficult       True
# ...                      ...                         ...        ...
# 88758               Too long                        Easy       True
# 88764                    NaN                         NaN       True
# 88786  Appropriate in length                        Easy       True
# 88818               Too long  Neither easy nor difficult       True
# 88844  Appropriate in length                        Easy       True
#
# [10083 rows x 86 columns]

# %%
len(df_usa_python)
# Out:
# 10083

# %%
#Reproduce the following

# %%
df_comp_3 = df.groupby('Country')['ConvertedComp'].median()
df_comp_4 = df_comp_3.loc[country_list]

data = list(df_comp_4.values)
keys = country_list
palette_color = sns.color_palette('bright')

plt.figure(figsize=(24, 8))
plt.pie(data,labels=keys, colors=palette_color, center=(0, 0))
plt.ylabel("ConvertedComp")
plt.show()

# %%
#Reproduce the following plot of US developer age in the x-axis and their
#salary in the y-axis

# %%
usa_age = df[df['Country'] == 'United States'][['Age', 'ConvertedComp']]
usa_age.reset_index(drop = True, inplace = True)

bins = [0.0, 18.0, 25.0, 35.0, 45.0, 55.0, 95.0]
usa_age['bin'] = pd.cut(usa_age['Age'], bins = bins,
                        labels = ['0-18.0', '18.0-25.0', '25.0-35.0', '35.0-45.0', '45.0-55.0', '55.0-95.0'])

ax = sns.barplot(data = usa_age, x = 'bin', y = 'ConvertedComp')
ax.set(xlabel = 'Age', title = 'Salaries of different age groups in USA')
sns.despine()
plt.show()

# %%
# Out:
# /Users/moussadoumbia/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/moussadoumbia/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/moussadoumbia/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Group the dataframe by Country and get the country "Zimbabwe" from it

# %%
df_zimbabwe = df[df['Country'] == 'Zimbabwe']
df_zimbabwe.head()
# Out:
#       Respondent                              MainBranch Hobbyist  \
# 249          251  I am a student who is learning to code      Yes
# 1878        1886          I am a developer by profession      Yes
# 2521        2530          I am a developer by profession      Yes
# 3829        3845          I am a developer by profession      Yes
# 3975        3991             I code primarily as a hobby      Yes
#
#                                             OpenSourcer  \
# 249                          Once a month or more often
# 1878  Less than once a month but more than once per ...
# 2521  Less than once a month but more than once per ...
# 3829                                              Never
# 3975                            Less than once per year
#
#                                              OpenSource  \
# 249   OSS is, on average, of HIGHER quality than pro...
# 1878  OSS is, on average, of HIGHER quality than pro...
# 2521  OSS is, on average, of LOWER quality than prop...
# 3829  The quality of OSS and closed source software ...
# 3975  OSS is, on average, of HIGHER quality than pro...
#
#                                              Employment   Country  \
# 249                  Not employed, but looking for work  Zimbabwe
# 1878                                 Employed full-time  Zimbabwe
# 2521                                 Employed full-time  Zimbabwe
# 3829                                 Employed full-time  Zimbabwe
# 3975  Independent contractor, freelancer, or self-em...  Zimbabwe
#
#              Student                                            EdLevel  \
# 249   Yes, full-time  Secondary school (e.g. American high school, G...
# 1878              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2521  Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3829              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3975              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                          UndergradMajor  ...  \
# 249                                                 NaN  ...
# 1878  Computer science, computer engineering, or sof...  ...
# 2521  Information systems, information technology, o...  ...
# 3829  Information systems, information technology, o...  ...
# 3975  Information systems, information technology, o...  ...
#
#                                           WelcomeChange  \
# 249               A lot more welcome now than last year
# 1878            Just as welcome now as I felt last year
# 2521            Just as welcome now as I felt last year
# 3829            Just as welcome now as I felt last year
# 3975  Not applicable - I did not use Stack Overflow ...
#
#                                            SONewContent   Age Gender Trans  \
# 249   Tech meetups or events in your area;Courses on...  20.0    Man    No
# 1878                Tech meetups or events in your area  27.0    Man    No
# 2521  Tech articles written by other developers;Indu...   NaN    Man    No
# 3829  Tech articles written by other developers;Indu...  28.0    Man    No
# 3975  Tech articles written by other developers;Indu...  46.0    Man    No
#
#                     Sexuality                    Ethnicity Dependents  \
# 249   Straight / Heterosexual  Black or of African descent         No
# 1878  Straight / Heterosexual  Black or of African descent        Yes
# 2521  Straight / Heterosexual  Black or of African descent        Yes
# 3829  Straight / Heterosexual  Black or of African descent         No
# 3975  Straight / Heterosexual  Black or of African descent        Yes
#
#                SurveyLength                  SurveyEase
# 249   Appropriate in length  Neither easy nor difficult
# 1878               Too long                        Easy
# 2521               Too long                        Easy
# 3829               Too long                        Easy
# 3975  Appropriate in length                        Easy
#
# [5 rows x 85 columns]

# %%
# Out:
#        ResponseId                                         MainBranch  \
# 8034         8035             I am a student who is learning to code
# 13194       13195                     I am a developer by profession
# 13273       13274                     I am a developer by profession
# 13395       13396                     I am a developer by profession
# 22782       22783                     I am a developer by profession
# 27472       27473  I am not primarily a developer, but I write co...
# 29070       29071                     I am a developer by profession
# 29692       29693                     I am a developer by profession
# 31652       31653                     I am a developer by profession
# 38428       38429                     I am a developer by profession
# 39746       39747                     I am a developer by profession
# 39906       39907             I am a student who is learning to code
# 41503       41504                     I am a developer by profession
# 44094       44095                     I am a developer by profession
# 46663       46664             I am a student who is learning to code
# 46797       46798                     I am a developer by profession
# 50221       50222                     I am a developer by profession
# 54148       54149                     I am a developer by profession
# 55450       55451                        I code primarily as a hobby
# 56302       56303             I am a student who is learning to code
# 59222       59223                     I am a developer by profession
# 61695       61696                     I am a developer by profession
# 63625       63626                     I am a developer by profession
# 64609       64610             I am a student who is learning to code
# 67209       67210                                      None of these
# 71232       71233             I am a student who is learning to code
# 71573       71574  I am not primarily a developer, but I write co...
# 72985       72986                     I am a developer by profession
# 73192       73193                     I am a developer by profession
# 73741       73742                     I am a developer by profession
# 75693       75694             I am a student who is learning to code
# 76082       76083                     I am a developer by profession
# 79301       79302             I am a student who is learning to code
# 80367       80368                     I am a developer by profession
# 80996       80997                        I code primarily as a hobby
# 82406       82407             I am a student who is learning to code
#
#                                               Employment   Country US_State  \
# 8034                                  Student, full-time  Zimbabwe      NaN
# 13194                                 Employed full-time  Zimbabwe      NaN
# 13273                                 Employed full-time  Zimbabwe      NaN
# 13395                 Not employed, but looking for work  Zimbabwe      NaN
# 22782                                 Employed full-time  Zimbabwe      NaN
# 27472                                 Employed part-time  Zimbabwe      NaN
# 29070                                 Employed full-time  Zimbabwe      NaN
# 29692                                 Employed full-time  Zimbabwe      NaN
# 31652                                 Employed full-time  Zimbabwe      NaN
# 38428                                 Employed full-time  Zimbabwe      NaN
# 39746                                 Employed full-time  Zimbabwe      NaN
# 39906                                 Student, full-time  Zimbabwe      NaN
# 41503                                 Employed full-time  Zimbabwe      NaN
# 44094                                 Employed full-time  Zimbabwe      NaN
# 46663                                I prefer not to say  Zimbabwe      NaN
# 46797  Independent contractor, freelancer, or self-em...  Zimbabwe      NaN
# 50221                                 Employed full-time  Zimbabwe      NaN
# 54148                                 Employed full-time  Zimbabwe      NaN
# 55450             Not employed, and not looking for work  Zimbabwe      NaN
# 56302                                 Student, full-time  Zimbabwe      NaN
# 59222  Independent contractor, freelancer, or self-em...  Zimbabwe      NaN
# 61695                                 Employed part-time  Zimbabwe      NaN
# 63625  Independent contractor, freelancer, or self-em...  Zimbabwe      NaN
# 64609                                 Student, full-time  Zimbabwe      NaN
# 67209                                I prefer not to say  Zimbabwe      NaN
# 71232                 Not employed, but looking for work  Zimbabwe      NaN
# 71573                 Not employed, but looking for work  Zimbabwe      NaN
# 72985  Independent contractor, freelancer, or self-em...  Zimbabwe      NaN
# 73192                                 Employed full-time  Zimbabwe      NaN
# 73741                                 Student, part-time  Zimbabwe      NaN
# 75693                                 Student, full-time  Zimbabwe      NaN
# 76082                 Not employed, but looking for work  Zimbabwe      NaN
# 79301                                 Student, part-time  Zimbabwe      NaN
# 80367                                 Employed part-time  Zimbabwe      NaN
# 80996             Not employed, and not looking for work  Zimbabwe      NaN
# 82406                                 Employed part-time  Zimbabwe      NaN
#
#       UK_Country                                            EdLevel  \
# 8034         NaN  Some college/university study without earning ...
# 13194        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 13273        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 13395        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 22782        NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 27472        NaN                Associate degree (A.A., A.S., etc.)
# 29070        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 29692        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 31652        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 38428        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 39746        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 39906        NaN  Some college/university study without earning ...
# 41503        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 44094        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 46663        NaN  Secondary school (e.g. American high school, G...
# 46797        NaN  Some college/university study without earning ...
# 50221        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 54148        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 55450        NaN  Some college/university study without earning ...
# 56302        NaN  Secondary school (e.g. American high school, G...
# 59222        NaN                                     Something else
# 61695        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 63625        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 64609        NaN  Secondary school (e.g. American high school, G...
# 67209        NaN                                     Something else
# 71232        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 71573        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 72985        NaN  Some college/university study without earning ...
# 73192        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73741        NaN  Some college/university study without earning ...
# 75693        NaN  Secondary school (e.g. American high school, G...
# 76082        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 79301        NaN  Secondary school (e.g. American high school, G...
# 80367        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 80996        NaN                          Primary/elementary school
# 82406        NaN  Some college/university study without earning ...
#
#                 Age1stCode                                          LearnCode  \
# 8034         18 - 24 years  Other online resources (ex: videos, blogs, etc...
# 13194        18 - 24 years  Other online resources (ex: videos, blogs, etc...
# 13273        18 - 24 years  Other online resources (ex: videos, blogs, etc...
# 13395        11 - 17 years                                             School
# 22782        25 - 34 years  Coding Bootcamp;Other online resources (ex: vi...
# 27472        18 - 24 years  Other online resources (ex: videos, blogs, etc...
# 29070        18 - 24 years  Other online resources (ex: videos, blogs, etc...
# 29692        25 - 34 years  Other online resources (ex: videos, blogs, etc...
# 31652        18 - 24 years  Other online resources (ex: videos, blogs, etc...
# 38428         5 - 10 years  Coding Bootcamp;Other online resources (ex: vi...
# 39746        18 - 24 years  Other online resources (ex: videos, blogs, etc...
# 39906        11 - 17 years                                             School
# 41503        18 - 24 years  Other online resources (ex: videos, blogs, etc...
# 44094        25 - 34 years  Other online resources (ex: videos, blogs, etc...
# 46663        11 - 17 years                    Online Courses or Certification
# 46797        25 - 34 years  Other online resources (ex: videos, blogs, etc...
# 50221        11 - 17 years     Friend or family member;Books / Physical media
# 54148        18 - 24 years  Other online resources (ex: videos, blogs, etc...
# 55450        18 - 24 years                             Books / Physical media
# 56302        18 - 24 years                             Books / Physical media
# 59222         5 - 10 years  Other online resources (ex: videos, blogs, etc...
# 61695        11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 63625        11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 64609        18 - 24 years                                             School
# 67209  Older than 64 years                            Other (please specify):
# 71232        18 - 24 years  School;Online Courses or Certification;Books /...
# 71573        11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 72985        18 - 24 years                     School;Other (please specify):
# 73192        18 - 24 years  Other online resources (ex: videos, blogs, etc...
# 73741        11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 75693        18 - 24 years  Other online resources (ex: videos, blogs, etc...
# 76082        18 - 24 years  Other online resources (ex: videos, blogs, etc...
# 79301        35 - 44 years    Other online resources (ex: videos, blogs, etc)
# 80367        25 - 34 years  Coding Bootcamp;Other online resources (ex: vi...
# 80996        11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 82406        18 - 24 years                      School;Books / Physical media
#
#                 YearsCode        YearsCodePro  \
# 8034                    3                 NaN
# 13194                  18                  14
# 13273                   6                   2
# 13395                 NaN                 NaN
# 22782                  15                  11
# 27472                  12                   9
# 29070                   4                   2
# 29692                   8                   3
# 31652                   4                   3
# 38428                  10                   6
# 39746                   5                   2
# 39906                   4                 NaN
# 41503                   5                   1
# 44094                   7                   6
# 46663                 NaN                 NaN
# 46797                   6                   3
# 50221                  20                   8
# 54148                  13                   9
# 55450    Less than 1 year                 NaN
# 56302                   1                 NaN
# 59222                  10                   3
# 61695                   8                   4
# 63625                   5                   3
# 64609                   3                 NaN
# 67209  More than 50 years  More than 50 years
# 71232                   4                 NaN
# 71573                   1                 NaN
# 72985                  24                  20
# 73192                   5                   1
# 73741                   5                 NaN
# 75693                   2                 NaN
# 76082                   3                 NaN
# 79301                   1                 NaN
# 80367                   6                   2
# 80996    Less than 1 year                 NaN
# 82406                   3                 NaN
#
#                                                  DevType  \
# 8034                                                 NaN
# 13194  Developer, back-end;Database administrator;Sys...
# 13273  Developer, mobile;Developer, front-end;Develop...
# 13395  Developer, mobile;Developer, front-end;Develop...
# 22782  Developer, mobile;Developer, front-end;Develop...
# 27472  Developer, mobile;Developer, front-end;Designe...
# 29070  Developer, front-end;Developer, full-stack;Dat...
# 29692  Developer, mobile;Developer, front-end;Develop...
# 31652                              Developer, full-stack
# 38428  Developer, mobile;Developer, front-end;Develop...
# 39746  Developer, front-end;Developer, desktop or ent...
# 39906                                                NaN
# 41503                              Developer, full-stack
# 44094              Developer, mobile;Developer, back-end
# 46663                                                NaN
# 46797  Developer, front-end;Developer, desktop or ent...
# 50221  DevOps specialist;Engineer, site reliability;S...
# 54148  Developer, front-end;Developer, desktop or ent...
# 55450                                                NaN
# 56302                                                NaN
# 59222  Developer, mobile;Developer, desktop or enterp...
# 61695  Developer, mobile;Developer, front-end;Develop...
# 63625  Developer, mobile;Developer, full-stack;Databa...
# 64609                                                NaN
# 67209                                                NaN
# 71232                                            Student
# 71573                                            Student
# 72985  Developer, desktop or enterprise applications;...
# 73192                              Developer, full-stack
# 73741                                                NaN
# 75693                                                NaN
# 76082                              Developer, full-stack
# 79301                                                NaN
# 80367              Developer, front-end;Student;Designer
# 80996                                                NaN
# 82406  Developer, front-end;Developer, back-end;Datab...
#
#                                                  OrgSize  \
# 8034                                                 NaN
# 13194                                   2 to 9 employees
# 13273                               100 to 499 employees
# 13395                                                NaN
# 22782                                 20 to 99 employees
# 27472                                   2 to 9 employees
# 29070                                 10 to 19 employees
# 29692                               100 to 499 employees
# 31652                               100 to 499 employees
# 38428                           10,000 or more employees
# 39746                                 10 to 19 employees
# 39906                                                NaN
# 41503                           1,000 to 4,999 employees
# 44094                                 20 to 99 employees
# 46663                                                NaN
# 46797  Just me - I am a freelancer, sole proprietor, ...
# 50221                               100 to 499 employees
# 54148                                 10 to 19 employees
# 55450                                                NaN
# 56302                                                NaN
# 59222                                   2 to 9 employees
# 61695                                   2 to 9 employees
# 63625  Just me - I am a freelancer, sole proprietor, ...
# 64609                                                NaN
# 67209                                                NaN
# 71232                                                NaN
# 71573                                                NaN
# 72985  Just me - I am a freelancer, sole proprietor, ...
# 73192                                 10 to 19 employees
# 73741                                                NaN
# 75693                                                NaN
# 76082                                                NaN
# 79301                                                NaN
# 80367                           10,000 or more employees
# 80996                                                NaN
# 82406                                                NaN
#
#                         Currency  CompTotal CompFreq  \
# 8034                         NaN        NaN      NaN
# 13194  USD\tUnited States dollar        NaN      NaN
# 13273  USD\tUnited States dollar        NaN  Monthly
# 13395                        NaN        NaN      NaN
# 22782  USD\tUnited States dollar        NaN  Monthly
# 27472  USD\tUnited States dollar     3000.0  Monthly
# 29070  USD\tUnited States dollar      600.0  Monthly
# 29692  USD\tUnited States dollar     1000.0  Monthly
# 31652  USD\tUnited States dollar      300.0  Monthly
# 38428  USD\tUnited States dollar        NaN      NaN
# 39746  USD\tUnited States dollar      195.0  Monthly
# 39906                        NaN        NaN      NaN
# 41503  USD\tUnited States dollar     1100.0  Monthly
# 44094  USD\tUnited States dollar        NaN  Monthly
# 46663                        NaN        NaN      NaN
# 46797  USD\tUnited States dollar      400.0   Weekly
# 50221  USD\tUnited States dollar     2000.0  Monthly
# 54148  USD\tUnited States dollar     1461.0  Monthly
# 55450                        NaN        NaN      NaN
# 56302                        NaN        NaN      NaN
# 59222  USD\tUnited States dollar        NaN      NaN
# 61695  USD\tUnited States dollar     4000.0   Yearly
# 63625  USD\tUnited States dollar       10.0  Monthly
# 64609                        NaN        NaN      NaN
# 67209                        NaN        NaN      NaN
# 71232                        NaN        NaN      NaN
# 71573                        NaN        NaN      NaN
# 72985  USD\tUnited States dollar        NaN      NaN
# 73192  USD\tUnited States dollar      200.0  Monthly
# 73741                        NaN        NaN      NaN
# 75693                        NaN        NaN      NaN
# 76082                        NaN        NaN      NaN
# 79301                        NaN        NaN      NaN
# 80367  USD\tUnited States dollar      500.0  Monthly
# 80996                        NaN        NaN      NaN
# 82406                        NaN        NaN      NaN
#
#                                   LanguageHaveWorkedWith  \
# 8034                               C;HTML/CSS;JavaScript
# 13194                                               Rust
# 13273  Assembly;Bash/Shell;C;C#;C++;Dart;Go;HTML/CSS;...
# 13395                Bash/Shell;Java;Rust;SQL;TypeScript
# 22782  C;C#;C++;Delphi;HTML/CSS;Java;JavaScript;LISP;...
# 27472                     HTML/CSS;JavaScript;TypeScript
# 29070  C#;C++;HTML/CSS;Java;JavaScript;Node.js;PHP;SQ...
# 29692           C;C#;C++;Crystal;HTML/CSS;JavaScript;SQL
# 31652  HTML/CSS;JavaScript;Node.js;PHP;Python;SQL;Typ...
# 38428                                          Dart;Java
# 39746                          Bash/Shell;PHP;Python;SQL
# 39906                             C#;HTML/CSS;JavaScript
# 41503  Dart;HTML/CSS;Java;JavaScript;Node.js;PHP;SQL;...
# 44094                          Dart;Go;Java;Python;Scala
# 46663                                             Python
# 46797                                             C#;SQL
# 50221                         HTML/CSS;JavaScript;Python
# 54148                             C#;HTML/CSS;JavaScript
# 55450                                           C;Python
# 56302             APL;HTML/CSS;JavaScript;Node.js;Python
# 59222                               Dart;HTML/CSS;Python
# 61695                         C#;Java;JavaScript;Node.js
# 63625   Bash/Shell;C;C++;HTML/CSS;Java;JavaScript;Python
# 64609                C;C#;C++;HTML/CSS;Java;Python;R;SQL
# 67209                                                NaN
# 71232  C;C++;Dart;HTML/CSS;Java;JavaScript;PHP;Python...
# 71573             Bash/Shell;HTML/CSS;JavaScript;Node.js
# 72985                              C#;JavaScript;PHP;SQL
# 73192                                                 C#
# 73741  Bash/Shell;C#;Go;HTML/CSS;JavaScript;PowerShel...
# 75693                                             Python
# 76082                    C++;Dart;Java;JavaScript;Python
# 79301                                                NaN
# 80367                HTML/CSS;Java;JavaScript;TypeScript
# 80996                 HTML/CSS;JavaScript;Node.js;Python
# 82406                           C#;JavaScript;PHP;Python
#
#                                   LanguageWantToWorkWith  \
# 8034   C;HTML/CSS;Java;JavaScript;Node.js;Python;SQL;...
# 13194                                               Rust
# 13273  Go;HTML/CSS;JavaScript;Kotlin;Node.js;PHP;Powe...
# 13395                                Rust;SQL;TypeScript
# 22782  C++;Delphi;HTML/CSS;Java;JavaScript;Node.js;Ob...
# 27472            HTML/CSS;Java;JavaScript;Node.js;Python
# 29070                                                 C#
# 29692    C;C#;Crystal;HTML/CSS;JavaScript;SQL;TypeScript
# 31652  HTML/CSS;JavaScript;Node.js;PHP;PowerShell;Pyt...
# 38428                                          Dart;Java
# 39746                   C#;JavaScript;Node.js;TypeScript
# 39906            C#;HTML/CSS;JavaScript;PHP;Python;Swift
# 41503  C#;Dart;Go;HTML/CSS;Java;JavaScript;Node.js;PH...
# 44094                         Dart;Go;Java;Kotlin;Python
# 46663                                                NaN
# 46797                                             C#;SQL
# 50221                         HTML/CSS;JavaScript;Python
# 54148           C#;HTML/CSS;JavaScript;Python;TypeScript
# 55450                                  Assembly;C++;Rust
# 56302                                    Java;TypeScript
# 59222                               Dart;HTML/CSS;Python
# 61695                                                NaN
# 63625             HTML/CSS;Java;JavaScript;Kotlin;Python
# 64609                                                NaN
# 67209                                                NaN
# 71232                                                NaN
# 71573  Bash/Shell;Dart;HTML/CSS;Java;JavaScript;Node....
# 72985                              C#;JavaScript;PHP;SQL
# 73192                                                 C#
# 73741                                                NaN
# 75693                                HTML/CSS;JavaScript
# 76082                                        Dart;Python
# 79301                                                NaN
# 80367                              Matlab;PHP;Python;SQL
# 80996      Assembly;C#;C++;Go;Java;Kotlin;Node.js;Python
# 82406  C#;Java;JavaScript;Kotlin;Matlab;Node.js;PHP;P...
#
#                                   DatabaseHaveWorkedWith  \
# 8034                                      Firebase;MySQL
# 13194                                                NaN
# 13273  Cassandra;Firebase;MariaDB;Microsoft SQL Serve...
# 13395                           Firebase;MariaDB;MongoDB
# 22782  Firebase;IBM DB2;MariaDB;Microsoft SQL Server;...
# 27472                                              MySQL
# 29070                                       MySQL;SQLite
# 29692                               Microsoft SQL Server
# 31652                Elasticsearch;Firebase;MySQL;SQLite
# 38428                    Microsoft SQL Server;PostgreSQL
# 39746                       MariaDB;MongoDB;MySQL;SQLite
# 39906                                   MySQL;PostgreSQL
# 41503                    MongoDB;MySQL;PostgreSQL;SQLite
# 44094                                        MySQL;Redis
# 46663                                                NaN
# 46797                  Microsoft SQL Server;Redis;SQLite
# 50221  Elasticsearch;MariaDB;Microsoft SQL Server;MyS...
# 54148                               Microsoft SQL Server
# 55450                                                NaN
# 56302                            PostgreSQL;Redis;SQLite
# 59222                    Firebase;MySQL;PostgreSQL;Redis
# 61695              Firebase;Microsoft SQL Server;MongoDB
# 63625                            PostgreSQL;Redis;SQLite
# 64609                                              MySQL
# 67209                                                NaN
# 71232                                       MySQL;SQLite
# 71573                                 MongoDB;PostgreSQL
# 72985                  Microsoft SQL Server;MySQL;SQLite
# 73192                                                NaN
# 73741                                  PostgreSQL;SQLite
# 75693                                              MySQL
# 76082                                  PostgreSQL;SQLite
# 79301                            MySQL;PostgreSQL;SQLite
# 80367                                              MySQL
# 80996                                                NaN
# 82406                                              MySQL
#
#                                   DatabaseWantToWorkWith  \
# 8034                                      Firebase;MySQL
# 13194                                                NaN
# 13273  Elasticsearch;MongoDB;MySQL;PostgreSQL;Redis;S...
# 13395                                            MariaDB
# 22782  Firebase;MariaDB;Microsoft SQL Server;MySQL;Or...
# 27472                                      MongoDB;MySQL
# 29070                                       MySQL;SQLite
# 29692               Firebase;Microsoft SQL Server;SQLite
# 31652  Elasticsearch;Firebase;Microsoft SQL Server;Mo...
# 38428                    Microsoft SQL Server;PostgreSQL
# 39746           Firebase;Microsoft SQL Server;PostgreSQL
# 39906                                   MySQL;PostgreSQL
# 41503                    MongoDB;MySQL;PostgreSQL;SQLite
# 44094               Elasticsearch;MySQL;PostgreSQL;Redis
# 46663                                                NaN
# 46797       Microsoft SQL Server;PostgreSQL;Redis;SQLite
# 50221  Elasticsearch;MariaDB;Microsoft SQL Server;MyS...
# 54148            Microsoft SQL Server;MongoDB;PostgreSQL
# 55450                                                NaN
# 56302                                                NaN
# 59222                             MySQL;PostgreSQL;Redis
# 61695                                                NaN
# 63625     Elasticsearch;Firebase;PostgreSQL;Redis;SQLite
# 64609                                                NaN
# 67209                                                NaN
# 71232                                                NaN
# 71573                Firebase;MariaDB;MongoDB;PostgreSQL
# 72985                         Microsoft SQL Server;MySQL
# 73192                                                NaN
# 73741                                                NaN
# 75693                                                NaN
# 76082                                  PostgreSQL;SQLite
# 79301                            MySQL;PostgreSQL;SQLite
# 80367                                              MySQL
# 80996                                                NaN
# 82406               DynamoDB;MariaDB;MySQL;Oracle;SQLite
#
#                                   PlatformHaveWorkedWith  \
# 8034                                                 NaN
# 13194                                                NaN
# 13273                                DigitalOcean;Heroku
# 13395            AWS;IBM Cloud or Watson;Microsoft Azure
# 22782              Google Cloud Platform;Microsoft Azure
# 27472                                                NaN
# 29070                                             Heroku
# 29692  DigitalOcean;Google Cloud Platform;Heroku;Micr...
# 31652                                                NaN
# 38428                                                NaN
# 39746                                                NaN
# 39906                                                AWS
# 41503                                             Heroku
# 44094                                                NaN
# 46663                                                NaN
# 46797                                    Microsoft Azure
# 50221                                   AWS;DigitalOcean
# 54148                                    Microsoft Azure
# 55450                              Google Cloud Platform
# 56302                                             Heroku
# 59222                                             Heroku
# 61695                              Google Cloud Platform
# 63625                                       DigitalOcean
# 64609                                                NaN
# 67209                                                NaN
# 71232                                                NaN
# 71573                                                NaN
# 72985                                                NaN
# 73192                                                NaN
# 73741                                                NaN
# 75693                                                NaN
# 76082                                             Heroku
# 79301                                                NaN
# 80367                                                NaN
# 80996                                                NaN
# 82406                                                NaN
#
#                                   PlatformWantToWorkWith  \
# 8034                                                 NaN
# 13194                                                NaN
# 13273  AWS;DigitalOcean;Google Cloud Platform;Heroku;...
# 13395                                                NaN
# 22782      AWS;Google Cloud Platform;IBM Cloud or Watson
# 27472                                                NaN
# 29070                                             Heroku
# 29692              Google Cloud Platform;Microsoft Azure
# 31652                                                NaN
# 38428                                                NaN
# 39746                                                NaN
# 39906                                                AWS
# 41503                                             Heroku
# 44094                                                NaN
# 46663                                                NaN
# 46797                                AWS;Microsoft Azure
# 50221                                   AWS;DigitalOcean
# 54148                                AWS;Microsoft Azure
# 55450                                                NaN
# 56302                                       DigitalOcean
# 59222                                             Heroku
# 61695  AWS;DigitalOcean;Heroku;IBM Cloud or Watson;Mi...
# 63625                                       DigitalOcean
# 64609                                                NaN
# 67209                                                NaN
# 71232                                                NaN
# 71573                                                NaN
# 72985                                                NaN
# 73192                                                NaN
# 73741                                                NaN
# 75693                                                NaN
# 76082                                             Heroku
# 79301                                                NaN
# 80367                                                NaN
# 80996                                                NaN
# 82406                                                NaN
#
#                                   WebframeHaveWorkedWith  \
# 8034                                    Angular;React.js
# 13194                                                NaN
# 13273  Express;FastAPI;Flask;Gatsby;Laravel;React.js;...
# 13395                            Laravel;React.js;Vue.js
# 22782  Angular;Angular.js;ASP.NET Core ;jQuery;Larave...
# 27472                              Angular;Drupal;jQuery
# 29070             ASP.NET;Laravel;React.js;Spring;Vue.js
# 29692                              ASP.NET;ASP.NET Core
# 31652                                    Angular;Laravel
# 38428                                     Angular;Spring
# 39746                                ASP.NET Core ;Flask
# 39906                              ASP.NET;ASP.NET Core
# 41503  Angular;Express;jQuery;Laravel;React.js;Spring...
# 44094                           Angular.js;Django;Spring
# 46663                                                NaN
# 46797                     ASP.NET;ASP.NET Core ;React.js
# 50221                             FastAPI;Flask;React.js
# 54148                     ASP.NET;ASP.NET Core ;React.js
# 55450                                                NaN
# 56302                                     Flask;React.js
# 59222                                             Django
# 61695                                           React.js
# 63625                                      Django;jQuery
# 64609                                                NaN
# 67209                                                NaN
# 71232                                           React.js
# 71573                            Express;React.js;Spring
# 72985                                      ASP.NET Core
# 73192                                     ASP.NET;jQuery
# 73741                     Angular;Django;jQuery;React.js
# 75693                                             Django
# 76082                                             Django
# 79301                                             Django
# 80367                            Angular;React.js;Vue.js
# 80996                                           React.js
# 82406                                            ASP.NET
#
#                                   WebframeWantToWorkWith  \
# 8034                                    Angular;React.js
# 13194                                                NaN
# 13273             FastAPI;Gatsby;Laravel;React.js;Spring
# 13395                                           React.js
# 22782  ASP.NET Core ;jQuery;Laravel;React.js;Ruby on ...
# 27472                                    React.js;Vue.js
# 29070             ASP.NET;Laravel;React.js;Spring;Vue.js
# 29692                      Angular;ASP.NET;ASP.NET Core
# 31652       Angular;Django;Flask;Laravel;React.js;Vue.js
# 38428                                     Angular;Spring
# 39746  Angular;Django;Express;jQuery;Laravel;Svelte;V...
# 39906    Angular.js;ASP.NET;ASP.NET Core ;Flask;React.js
# 41503     Angular;Express;Laravel;React.js;Spring;Vue.js
# 44094                                    React.js;Vue.js
# 46663                                                NaN
# 46797                     ASP.NET;ASP.NET Core ;React.js
# 50221                     FastAPI;Flask;Laravel;React.js
# 54148                             ASP.NET Core ;React.js
# 55450                                                NaN
# 56302                              Drupal;FastAPI;Svelte
# 59222                                             Django
# 61695                     ASP.NET;Drupal;Express;Laravel
# 63625                                      Django;jQuery
# 64609                                                NaN
# 67209                                                NaN
# 71232                                                NaN
# 71573       Express;Gatsby;jQuery;React.js;Spring;Vue.js
# 72985                                      ASP.NET Core
# 73192                                     ASP.NET;jQuery
# 73741                                                NaN
# 75693                                            ASP.NET
# 76082                                             Django
# 79301                                    Django;React.js
# 80367                            Angular;React.js;Vue.js
# 80996                   Angular.js;Django;Express;jQuery
# 82406                           Angular.js;Django;jQuery
#
#                                   MiscTechHaveWorkedWith  \
# 8034                                                 NaN
# 13194                                                NaN
# 13273                         Flutter;NumPy;React Native
# 13395                                         TensorFlow
# 22782                  .NET Framework;.NET Core / .NET 5
# 27472                                            Cordova
# 29070                        .NET Framework;React Native
# 29692                  .NET Framework;.NET Core / .NET 5
# 31652                                            Cordova
# 38428                                            Flutter
# 39746                                     .NET Framework
# 39906                                            Flutter
# 41503                           Flutter;NumPy;TensorFlow
# 44094                                            Flutter
# 46663                                                NaN
# 46797                  .NET Framework;.NET Core / .NET 5
# 50221                                                NaN
# 54148                  .NET Framework;.NET Core / .NET 5
# 55450                                                NaN
# 56302                                            Cordova
# 59222                                            Flutter
# 61695  .NET Framework;.NET Core / .NET 5;Flutter;Reac...
# 63625                                       NumPy;Pandas
# 64609                                     .NET Framework
# 67209                                                NaN
# 71232                               Flutter;NumPy;Pandas
# 71573                                                NaN
# 72985                                 .NET Core / .NET 5
# 73192                                     .NET Framework
# 73741                                       NumPy;Pandas
# 75693                                            Flutter
# 76082                               Flutter;React Native
# 79301                                                NaN
# 80367                                                NaN
# 80996                                                NaN
# 82406                                     .NET Framework
#
#                                   MiscTechWantToWorkWith  \
# 8034                                                 NaN
# 13194                                                NaN
# 13273                     NumPy;TensorFlow;Torch/PyTorch
# 13395                                         TensorFlow
# 22782  .NET Framework;.NET Core / .NET 5;Flutter;Torc...
# 27472                                       React Native
# 29070                        .NET Framework;React Native
# 29692                  .NET Framework;.NET Core / .NET 5
# 31652                               Cordova;React Native
# 38428                                            Flutter
# 39746                                 .NET Core / .NET 5
# 39906                                            Flutter
# 41503                                            Flutter
# 44094                                            Flutter
# 46663                                                NaN
# 46797                  .NET Framework;.NET Core / .NET 5
# 50221                                                NaN
# 54148  .NET Core / .NET 5;Qt;React Native;TensorFlow;...
# 55450                                                NaN
# 56302                               Flutter;React Native
# 59222                                            Flutter
# 61695                                                NaN
# 63625                                       NumPy;Pandas
# 64609                                      Torch/PyTorch
# 67209                                                NaN
# 71232                                                NaN
# 71573                                                NaN
# 72985                                 .NET Core / .NET 5
# 73192                                     .NET Framework
# 73741                                                NaN
# 75693                                                NaN
# 76082                                            Flutter
# 79301                                                NaN
# 80367                                                NaN
# 80996                                                NaN
# 82406  .NET Framework;Flutter;NumPy;Pandas;Torch/PyTorch
#
#        ToolsTechHaveWorkedWith  \
# 8034                  Git;Yarn
# 13194                      Git
# 13273  Ansible;Docker;Git;Yarn
# 13395                     Yarn
# 22782                  Xamarin
# 27472                      Git
# 29070       Docker;Git;Xamarin
# 29692              Git;Xamarin
# 31652                 Git;Yarn
# 38428    Docker;Git;Kubernetes
# 39746               Docker;Git
# 39906                      NaN
# 41503         Deno;Git;Xamarin
# 44094               Docker;Git
# 46663                      NaN
# 46797                      Git
# 50221               Docker;Git
# 54148                      Git
# 55450                      NaN
# 56302                      Git
# 59222                      Git
# 61695                 Git;Yarn
# 63625               Docker;Git
# 64609                      Git
# 67209                      NaN
# 71232                      NaN
# 71573                      Git
# 72985                      NaN
# 73192                      Git
# 73741                      Git
# 75693                      NaN
# 76082                      Git
# 79301                      Git
# 80367                      NaN
# 80996                      NaN
# 82406                      NaN
#
#                               ToolsTechWantToWorkWith  \
# 8034                                              Git
# 13194                                             Git
# 13273                              Ansible;Docker;Git
# 13395                                            Yarn
# 22782                                      Docker;Git
# 27472                                             Git
# 29070                              Docker;Git;Xamarin
# 29692                   Docker;Git;Kubernetes;Xamarin
# 31652  Ansible;Chef;Docker;Git;Kubernetes;Puppet;Yarn
# 38428                           Docker;Git;Kubernetes
# 39746                      Ansible;Kubernetes;Xamarin
# 39906                                             NaN
# 41503                                             Git
# 44094                      Deno;Docker;Git;Kubernetes
# 46663                                             NaN
# 46797       Docker;Git;Unity 3D;Unreal Engine;Xamarin
# 50221          Docker;Git;Kubernetes;Pulumi;Terraform
# 54148                          Git;Kubernetes;Xamarin
# 55450                                             NaN
# 56302                                          Docker
# 59222                                      Docker;Git
# 61695                                    Xamarin;Yarn
# 63625                                      Docker;Git
# 64609                                             Git
# 67209                                             NaN
# 71232                                             NaN
# 71573                                      Docker;Git
# 72985                                             NaN
# 73192                                             Git
# 73741                                             NaN
# 75693                                             NaN
# 76082                                             Git
# 79301                              Ansible;Docker;Git
# 80367                                             NaN
# 80996                                             NaN
# 82406                                             NaN
#
#                             NEWCollabToolsHaveWorkedWith  \
# 8034                                  Visual Studio Code
# 13194                                                Vim
# 13273  Android Studio;Eclipse;IntelliJ;Sublime Text;V...
# 13395  Android Studio;IntelliJ;Neovim;Vim;Visual Stud...
# 22782  Android Studio;Atom;Eclipse;IntelliJ;NetBeans;...
# 27472  Android Studio;Notepad++;Visual Studio Code;Xcode
# 29070  IntelliJ;NetBeans;PHPStorm;Sublime Text;Visual...
# 29692                   Visual Studio;Visual Studio Code
# 31652                Sublime Text;Vim;Visual Studio Code
# 38428  Android Studio;Eclipse;IntelliJ;NetBeans;Notep...
# 39746                     Sublime Text;Vim;Visual Studio
# 39906  IntelliJ;PyCharm;Visual Studio;Visual Studio Code
# 41503               Android Studio;Sublime Text;Webstorm
# 44094  Android Studio;IntelliJ;Neovim;Vim;Visual Stud...
# 46663                                                NaN
# 46797         Notepad++;Visual Studio;Visual Studio Code
# 50221                                 Visual Studio Code
# 54148                   Visual Studio;Visual Studio Code
# 55450                                                NaN
# 56302                        Atom;Vim;Visual Studio Code
# 59222  Android Studio;Atom;IntelliJ;IPython/Jupyter;P...
# 61695  Android Studio;Atom;Eclipse;Notepad++;Visual S...
# 63625                       IPython/Jupyter;Sublime Text
# 64609  Android Studio;IPython/Jupyter;NetBeans;Notepa...
# 67209                                                NaN
# 71232             Android Studio;Atom;Visual Studio Code
# 71573                             IntelliJ;Visual Studio
# 72985         Notepad++;Visual Studio;Visual Studio Code
# 73192                   Visual Studio;Visual Studio Code
# 73741  Android Studio;IPython/Jupyter;Sublime Text;Vi...
# 75693                       Android Studio;Visual Studio
# 76082          IntelliJ;PyCharm;Visual Studio Code;Xcode
# 79301  Android Studio;PyCharm;Sublime Text;Visual Stu...
# 80367                Eclipse;IntelliJ;Visual Studio Code
# 80996               Notepad++;PyCharm;Visual Studio Code
# 82406  IPython/Jupyter;NetBeans;Notepad++;PyCharm;Sub...
#
#                             NEWCollabToolsWantToWorkWith  \
# 8034                                  Visual Studio Code
# 13194                                                Vim
# 13273     Android Studio;IntelliJ;Vim;Visual Studio Code
# 13395                          Neovim;Visual Studio Code
# 22782                 Notepad++;Visual Studio Code;Xcode
# 27472                                 Visual Studio Code
# 29070  Android Studio;IntelliJ;NetBeans;PHPStorm;Subl...
# 29692  IntelliJ;PyCharm;Visual Studio;Visual Studio Code
# 31652                             Vim;Visual Studio Code
# ...
# 63625               Multiple times per day                      Yes
# 64609                 A few times per week                      Yes
# 67209                                  NaN                      NaN
# 71232                 A few times per week                      Yes
# 71573                 A few times per week  Not sure/can't remember
# 72985      A few times per month or weekly                      Yes
# 73192      A few times per month or weekly                      Yes
# 73741                 A few times per week                      Yes
# 75693      A few times per month or weekly                      Yes
# 76082                Daily or almost daily                      Yes
# 79301                Daily or almost daily                      Yes
# 80367                 A few times per week                      Yes
# 80996      A few times per month or weekly                      Yes
# 82406                Daily or almost daily                      Yes
#
#                                               SOPartFreq           SOComm  \
# 8034                 Less than once per month or monthly    Yes, somewhat
# 13194  I have never participated in Q&A on Stack Over...    Yes, somewhat
# 13273                Less than once per month or monthly          Neutral
# 13395                    A few times per month or weekly    Yes, somewhat
# 22782                                                NaN   No, not really
# 27472                Less than once per month or monthly    Yes, somewhat
# 29070                                                NaN    Yes, somewhat
# 29692                                                NaN         Not sure
# 31652                                                NaN          Neutral
# 38428                                                NaN          Neutral
# 39746  I have never participated in Q&A on Stack Over...   No, not really
# 39906                Less than once per month or monthly          Neutral
# 41503                Less than once per month or monthly          Neutral
# 44094  I have never participated in Q&A on Stack Over...   No, not really
# 46663                                                NaN              NaN
# 46797                    A few times per month or weekly  Yes, definitely
# 50221                Less than once per month or monthly   No, not really
# 54148                    A few times per month or weekly    Yes, somewhat
# 55450                                                NaN         Not sure
# 56302  I have never participated in Q&A on Stack Over...          Neutral
# 59222                               A few times per week    Yes, somewhat
# 61695  I have never participated in Q&A on Stack Over...  Yes, definitely
# 63625                               A few times per week  Yes, definitely
# 64609                Less than once per month or monthly    Yes, somewhat
# 67209                                                NaN              NaN
# 71232                    A few times per month or weekly  Yes, definitely
# 71573                                                NaN   No, not really
# 72985  I have never participated in Q&A on Stack Over...    Yes, somewhat
# 73192                Less than once per month or monthly  Yes, definitely
# 73741  I have never participated in Q&A on Stack Over...  Yes, definitely
# 75693                Less than once per month or monthly    Yes, somewhat
# 76082                    A few times per month or weekly  Yes, definitely
# 79301                Less than once per month or monthly    Yes, somewhat
# 80367  I have never participated in Q&A on Stack Over...  Yes, definitely
# 80996  I have never participated in Q&A on Stack Over...   No, not really
# 82406                              Daily or almost daily  Yes, definitely
#
#       NEWOtherComms   Age                  Gender                   Trans  \
# 8034            Yes  18.0                     Man                      No
# 13194           Yes  35.0                     Man                      No
# 13273           Yes  25.0                     Man                      No
# 13395           Yes  18.0                     Man                      No
# 22782            No  25.0                     Man                      No
# 27472            No  25.0                     Man                      No
# 29070           Yes  18.0                     Man                      No
# 29692            No  25.0                     Man                      No
# 31652           Yes  18.0                     Man                      No
# 38428            No  25.0                   Woman                      No
# 39746           Yes  25.0                     Man                      No
# 39906           Yes  18.0                     Man                      No
# 41503            No  18.0                     Man                      No
# 44094            No   NaN                     Man                      No
# 46663           NaN   NaN                     Man                     NaN
# 46797            No  35.0                     Man                      No
# 50221            No  25.0                     Man                      No
# 54148           Yes  35.0                     Man                      No
# 55450            No  18.0                     Man                      No
# 56302            No  18.0                     Man                      No
# 59222           Yes  18.0                     Man                      No
# 61695           Yes  25.0                     Man                      No
# 63625            No  25.0                     Man                      No
# 64609           Yes  18.0                     Man       Prefer not to say
# 67209            No   NaN  Or, in your own words:  Or, in your own words:
# 71232            No  18.0                     Man                      No
# 71573            No  18.0                     Man                      No
# 72985            No  35.0                     Man                      No
# 73192            No  25.0                     Man                      No
# 73741           Yes  18.0                     Man                      No
# 75693           Yes  18.0                     Man                      No
# 76082           Yes  18.0                     Man                      No
# 79301            No  35.0                     Man                      No
# 80367           Yes  25.0                   Woman                      No
# 80996            No   NaN                     Man                      No
# 82406            No  18.0                     Man       Prefer not to say
#
#                       Sexuality                     Ethnicity  \
# 8034    Straight / Heterosexual   Black or of African descent
# 13194   Straight / Heterosexual   Black or of African descent
# 13273   Straight / Heterosexual   Black or of African descent
# 13395   Straight / Heterosexual   Black or of African descent
# 22782   Straight / Heterosexual   Black or of African descent
# 27472   Straight / Heterosexual   Black or of African descent
# 29070   Straight / Heterosexual   Black or of African descent
# 29692   Straight / Heterosexual   Black or of African descent
# 31652   Straight / Heterosexual   Black or of African descent
# 38428   Straight / Heterosexual   Black or of African descent
# 39746   Straight / Heterosexual   Black or of African descent
# 39906   Straight / Heterosexual   Black or of African descent
# 41503   Straight / Heterosexual   Black or of African descent
# 44094   Straight / Heterosexual   Black or of African descent
# 46663                       NaN   Black or of African descent
# 46797   Straight / Heterosexual   Black or of African descent
# 50221   Straight / Heterosexual   Black or of African descent
# 54148   Straight / Heterosexual   Black or of African descent
# 55450   Straight / Heterosexual   Black or of African descent
# 56302   Straight / Heterosexual   Black or of African descent
# 59222   Straight / Heterosexual   Black or of African descent
# 61695   Straight / Heterosexual   Black or of African descent
# 63625   Straight / Heterosexual   Black or of African descent
# 64609         Prefer not to say   Black or of African descent
# 67209  Prefer to self-describe:        Or, in your own words:
# 71232   Straight / Heterosexual   Black or of African descent
# 71573   Straight / Heterosexual   Black or of African descent
# 72985   Straight / Heterosexual  White or of European descent
# 73192   Straight / Heterosexual   Black or of African descent
# 73741   Straight / Heterosexual   Black or of African descent
# 75693   Straight / Heterosexual   Black or of African descent
# 76082   Straight / Heterosexual   Black or of African descent
# 79301                       NaN   Black or of African descent
# 80367   Straight / Heterosexual   Black or of African descent
# 80996   Straight / Heterosexual   Black or of African descent
# 82406   Straight / Heterosexual   Black or of African descent
#
#                              Accessibility  \
# 8034                     None of the above
# 13194                    None of the above
# 13273                    None of the above
# 13395                    None of the above
# 22782                    None of the above
# 27472                    None of the above
# 29070                    None of the above
# 29692               Or, in your own words:
# 31652                    None of the above
# 38428                    None of the above
# 39746                    None of the above
# 39906                    None of the above
# 41503                    None of the above
# 44094                    Prefer not to say
# 46663                                  NaN
# 46797                    None of the above
# 50221                    None of the above
# 54148                    None of the above
# 55450                    None of the above
# 56302                    None of the above
# 59222                    None of the above
# 61695                                  NaN
# 63625                    None of the above
# 64609                    None of the above
# 67209               Or, in your own words:
# 71232                    None of the above
# 71573                    None of the above
# 72985                    None of the above
# 73192                    None of the above
# 73741                    None of the above
# 75693                    None of the above
# 76082                    None of the above
# 79301                    None of the above
# 80367                    None of the above
# 80996  I am blind / have difficulty seeing
# 82406                    None of the above
#
#                                             MentalHealth  \
# 8034                                   None of the above
# 13194                                  None of the above
# 13273                                  None of the above
# 13395  I have a mood or emotional disorder (e.g. depr...
# 22782                                  None of the above
# 27472                                  None of the above
# 29070                                  None of the above
# 29692                                  None of the above
# 31652                                  None of the above
# 38428                                  None of the above
# 39746                                  None of the above
# 39906                                  None of the above
# 41503                                  None of the above
# 44094                                  None of the above
# 46663                                                NaN
# 46797                                  None of the above
# 50221                                  None of the above
# 54148                                  None of the above
# 55450                                  None of the above
# 56302                                  None of the above
# 59222                                  None of the above
# 61695                                                NaN
# 63625                                  None of the above
# 64609                                  None of the above
# 67209                             Or, in your own words:
# 71232                                  None of the above
# 71573                                  Prefer not to say
# 72985                                  None of the above
# 73192                                  None of the above
# 73741                                  None of the above
# 75693                         I have an anxiety disorder
# 76082                                  None of the above
# 79301                                  None of the above
# 80367                                  None of the above
# 80996                                  None of the above
# 82406                                  None of the above
#
#                 SurveyLength                  SurveyEase  ConvertedCompYearly
# 8034   Appropriate in length                        Easy                  NaN
# 13194               Too long                        Easy                  NaN
# 13273              Too short                        Easy                  NaN
# 13395  Appropriate in length                        Easy                  NaN
# 22782               Too long                        Easy                  NaN
# 27472  Appropriate in length                        Easy              36000.0
# 29070  Appropriate in length  Neither easy nor difficult               7200.0
# 29692  Appropriate in length                        Easy              12000.0
# 31652  Appropriate in length  Neither easy nor difficult               3600.0
# 38428  Appropriate in length  Neither easy nor difficult                  NaN
# 39746  Appropriate in length  Neither easy nor difficult               2340.0
# 39906  Appropriate in length                        Easy                  NaN
# 41503               Too long  Neither easy nor difficult              13200.0
# 44094              Too short  Neither easy nor difficult                  NaN
# 46663               Too long  Neither easy nor difficult                  NaN
# 46797  Appropriate in length                        Easy              20000.0
# 50221  Appropriate in length                        Easy              24000.0
# 54148  Appropriate in length                        Easy              17532.0
# 55450  Appropriate in length  Neither easy nor difficult                  NaN
# 56302  Appropriate in length                        Easy                  NaN
# 59222  Appropriate in length  Neither easy nor difficult                  NaN
# 61695               Too long  Neither easy nor difficult               4000.0
# 63625  Appropriate in length                        Easy                120.0
# 64609  Appropriate in length                        Easy                  NaN
# 67209               Too long                   Difficult                  NaN
# 71232               Too long  Neither easy nor difficult                  NaN
# 71573              Too short                        Easy                  NaN
# 72985  Appropriate in length                        Easy                  NaN
# 73192  Appropriate in length                        Easy               2400.0
# 73741  Appropriate in length  Neither easy nor difficult                  NaN
# 75693  Appropriate in length  Neither easy nor difficult                  NaN
# 76082  Appropriate in length                        Easy                  NaN
# 79301               Too long                         NaN                  NaN
# 80367  Appropriate in length                        Easy               6000.0
# 80996  Appropriate in length                        Easy                  NaN
# 82406                    NaN  Neither easy nor difficult                  NaN

# %%
df_zimbabwe['NEWStuck']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'NEWStuck'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[146], line 1
# ----> 1 df_zimbabwe['NEWStuck']
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'NEWStuck'

# %%
#Produce the following, which represent the first 20 NEWStuck in Zimbabwe
# Out:
# 8034     Visit Stack Overflow;Google it;Watch help / tu...
# 13194    Visit Stack Overflow;Google it;Watch help / tu...
# 13273    Call a coworker or friend;Visit Stack Overflow...
# 13395    Visit Stack Overflow;Go for a walk or other ph...
# 22782               Google it;Watch help / tutorial videos
# 27472    Visit Stack Overflow;Google it;Watch help / tu...
# 29070    Visit Stack Overflow;Google it;Watch help / tu...
# 29692    Call a coworker or friend;Visit Stack Overflow...
# 31652    Visit Stack Overflow;Go for a walk or other ph...
# 38428    Visit Stack Overflow;Go for a walk or other ph...
# 39746    Visit Stack Overflow;Go for a walk or other ph...
# 39906    Visit Stack Overflow;Google it;Do other work a...
# 41503    Visit Stack Overflow;Google it;Do other work a...
# 44094    Call a coworker or friend;Visit Stack Overflow...
# 46663                                            Google it
# 46797    Call a coworker or friend;Visit Stack Overflow...
# 50221    Visit Stack Overflow;Watch help / tutorial vid...
# 54148    Call a coworker or friend;Visit Stack Overflow...
# 55450    Visit Stack Overflow;Go for a walk or other ph...
# 56302                 Visit Stack Overflow;Google it;Panic
# Name: NEWStuck, dtype: object

# %%
df_zimbabwe['SOVisitTo'].iloc[0:20]
# Out:
# 249      Get a sense of belonging to the developer comm...
# 1878     Find answers to specific questions;Contribute ...
# 2521     Find answers to specific questions;Learn how t...
# 3829                    Find answers to specific questions
# 3975     Find answers to specific questions;Learn how t...
# 5087     Find answers to specific questions;Contribute ...
# 6460     Find answers to specific questions;Learn how t...
# 6466                    Find answers to specific questions
# 11007                   Find answers to specific questions
# 13329                   Find answers to specific questions
# 15220                   Find answers to specific questions
# 15847                   Find answers to specific questions
# 18604    Find answers to specific questions;Get a sense...
# 21851                   Find answers to specific questions
# 22241                   Find answers to specific questions
# 22848    Find answers to specific questions;Learn how t...
# 23033    Find answers to specific questions;Learn how t...
# 26077    Find answers to specific questions;Learn how t...
# 30560    Find answers to specific questions;Learn how t...
# 32759    Find answers to specific questions;Contribute ...
# Name: SOVisitTo, dtype: object

# %%
#how many people responded to the survey?
# Out:
# Country
# United States of America                                15288
# India                                                   10511
# Germany                                                  5625
# United Kingdom of Great Britain and Northern Ireland     4475
# Canada                                                   3012
# France                                                   2708
# Brazil                                                   2254
# Poland                                                   1805
# Netherlands                                              1772
# Italy                                                    1666
# Australia                                                1646
# Spain                                                    1485
# Russian Federation                                       1474
# Sweden                                                   1196
# China                                                    1055
# Turkey                                                   1054
# Switzerland                                               922
# Israel                                                    913
# Iran, Islamic Republic of...                              900
# Pakistan                                                  838
# Austria                                                   808
# Czech Republic                                            792
# Ukraine                                                   770
# Bangladesh                                                704
# Belgium                                                   697
# Mexico                                                    695
# Romania                                                   650
# Indonesia                                                 632
# Greece                                                    603
# Norway                                                    602
# Denmark                                                   599
# Argentina                                                 587
# South Africa                                              571
# Portugal                                                  530
# Finland                                                   528
# New Zealand                                               522
# Egypt                                                     521
# Hungary                                                   478
# Japan                                                     429
# Nigeria                                                   409
# Bulgaria                                                  402
# Sri Lanka                                                 396
# Viet Nam                                                  386
# Ireland                                                   386
# Philippines                                               382
# Colombia                                                  381
# Singapore                                                 339
# Nepal                                                     337
# Malaysia                                                  333
# Serbia                                                    310
# Taiwan                                                    302
# Kenya                                                     263
# Slovakia                                                  252
# Croatia                                                   250
# Slovenia                                                  235
# Chile                                                     230
# Lithuania                                                 208
# Morocco                                                   204
# Hong Kong (S.A.R.)                                        198
# South Korea                                               189
# Thailand                                                  184
# United Arab Emirates                                      182
# Belarus                                                   165
# Georgia                                                   161
# Tunisia                                                   150
# Peru                                                      147
# Uruguay                                                   144
# Saudi Arabia                                              137
# Bosnia and Herzegovina                                    130
# Estonia                                                   130
# Lebanon                                                   113
# Latvia                                                    107
# Dominican Republic                                        104
# Venezuela, Bolivarian Republic of...                      104
# Ecuador                                                   103
# Armenia                                                    92
# Ghana                                                      91
# Costa Rica                                                 77
# Iraq                                                       76
# Albania                                                    73
# Jordan                                                     72
# Ethiopia                                                   69
# Uzbekistan                                                 68
# Afghanistan                                                65
# Kazakhstan                                                 65
# Azerbaijan                                                 64
# Uganda                                                     63
# Guatemala                                                  58
# Cyprus                                                     56
# Myanmar                                                    55
# Republic of Moldova                                        55
# Republic of Korea                                          54
# Nomadic                                                    54
# The former Yugoslav Republic of Macedonia                  54
# Luxembourg                                                 51
# Syrian Arab Republic                                       51
# Bolivia                                                    48
# Paraguay                                                   47
# Algeria                                                    46
# Kosovo                                                     45
# United Republic of Tanzania                                43
# Iceland                                                    43
# Malta                                                      42
# Cameroon                                                   38
# Zimbabwe                                                   36
# Cambodia                                                   35
# Rwanda                                                     34
# Cuba                                                       34
# El Salvador                                                32
# Panama                                                     31
# Mauritius                                                  31
# Qatar                                                      29
# Kuwait                                                     29
# Bahrain                                                    28
# Senegal                                                    28
# Angola                                                     27
# Sudan                                                      27
# Palestine                                                  25
# Honduras                                                   24
# Zambia                                                     22
# Mongolia                                                   21
# Kyrgyzstan                                                 21
# Jamaica                                                    20
# Trinidad and Tobago                                        20
# Yemen                                                      20
# Oman                                                       20
# Nicaragua                                                  18
# Madagascar                                                 18
# Montenegro                                                 17
# Côte d'Ivoire                                              17
# Maldives                                                   16
# Benin                                                      15
# Turkmenistan                                               13
# Mozambique                                                 12
# Namibia                                                    12
# Andorra                                                    12
# Barbados                                                   12
# Congo, Republic of the...                                  12
# Libyan Arab Jamahiriya                                     11
# Malawi                                                     11
# Democratic Republic of the Congo                           10
# Swaziland                                                  10
# Tajikistan                                                  9
# Bahamas                                                     7
# Togo                                                        7
# Somalia                                                     7
# Guyana                                                      7
# Botswana                                                    6
# Cape Verde                                                  6
# North Korea                                                 6
# Haiti                                                       5
# Belize                                                      5
# Isle of Man                                                 5
# Mauritania                                                  5
# Bhutan                                                      5
# Suriname                                                    5
# Burundi                                                     5
# Fiji                                                        4
# Burkina Faso                                                4
# Lesotho                                                     4
# Lao People's Democratic Republic                            4
# Niger                                                       3
# Central African Republic                                    3
# Liberia                                                     3
# Saint Lucia                                                 3
# Djibouti                                                    3
# San Marino                                                  2
# Guinea                                                      2
# Sierra Leone                                                2
# Micronesia, Federated States of...                          2
# Chad                                                        2
# Gambia                                                      2
# Monaco                                                      2
# Mali                                                        2
# Brunei Darussalam                                           1
# Liechtenstein                                               1
# Saint Kitts and Nevis                                       1
# Dominica                                                    1
# Saint Vincent and the Grenadines                            1
# Tuvalu                                                      1
# Papua New Guinea                                            1
# Name: count, dtype: int64

# %%
df_participants = df['Country'].value_counts()
print(df_participants.to_string())
print(f'Name: count, dtype: {df_participants.dtype}')
# Out:
# Country
# United States                                20949
# India                                         9061
# Germany                                       5866
# United Kingdom                                5737
# Canada                                        3395
# France                                        2391
# Brazil                                        1948
# Poland                                        1922
# Australia                                     1903
# Netherlands                                   1852
# Russian Federation                            1694
# Spain                                         1604
# Italy                                         1576
# Sweden                                        1274
# Switzerland                                    978
# Israel                                         952
# Turkey                                         949
# Pakistan                                       923
# Ukraine                                        868
# Austria                                        839
# Czech Republic                                 764
# Romania                                        760
# Iran                                           738
# Belgium                                        727
# China                                          664
# Bulgaria                                       659
# Mexico                                         642
# South Africa                                   627
# Denmark                                        617
# Bangladesh                                     605
# Norway                                         574
# Greece                                         556
# Argentina                                      553
# Finland                                        546
# Portugal                                       525
# New Zealand                                    524
# Nigeria                                        522
# Hungary                                        513
# Indonesia                                      507
# Ireland                                        501
# Serbia                                         402
# Japan                                          391
# Philippines                                    381
# Sri Lanka                                      372
# Egypt                                          323
# Colombia                                       313
# Singapore                                      303
# Malaysia                                       299
# Slovenia                                       298
# Slovakia                                       260
# Croatia                                        260
# Kenya                                          249
# Lithuania                                      248
# Nepal                                          237
# Viet Nam                                       231
# Thailand                                       214
# Chile                                          206
# Belarus                                        202
# Estonia                                        195
# Hong Kong (S.A.R.)                             188
# Taiwan                                         187
# South Korea                                    160
# United Arab Emirates                           158
# Morocco                                        155
# Other Country (Not Listed Above)               136
# Latvia                                         136
# Algeria                                        134
# Tunisia                                        130
# Peru                                           130
# Lebanon                                        120
# Uruguay                                        111
# Bosnia and Herzegovina                         108
# Saudi Arabia                                    98
# Dominican Republic                              97
# Venezuela, Bolivarian Republic of...            88
# Albania                                         86
# Armenia                                         86
# Costa Rica                                      84
# Ghana                                           84
# Ecuador                                         82
# Georgia                                         80
# Uganda                                          72
# Guatemala                                       67
# El Salvador                                     67
# Malta                                           65
# Jordan                                          65
# Kazakhstan                                      64
# Cyprus                                          64
# Luxembourg                                      61
# The former Yugoslav Republic of Macedonia       54
# Paraguay                                        52
# Ethiopia                                        52
# Myanmar                                         52
# Cameroon                                        51
# Azerbaijan                                      49
# Iceland                                         49
# Afghanistan                                     44
# Republic of Moldova                             43
# Sudan                                           42
# Iraq                                            39
# Zimbabwe                                        39
# Uzbekistan                                      39
# Republic of Korea                               39
# Bolivia                                         36
# Côte d'Ivoire                                   34
# Panama                                          33
# United Republic of Tanzania                     32
# Cambodia                                        30
# Cuba                                            30
# Nicaragua                                       30
# Syrian Arab Republic                            29
# Jamaica                                         28
# Honduras                                        27
# Mauritius                                       26
# Senegal                                         21
# Kuwait                                          20
# Yemen                                           19
# Trinidad and Tobago                             19
# Kyrgyzstan                                      19
# Bahrain                                         18
# Mongolia                                        17
# Montenegro                                      17
# Madagascar                                      15
# Somalia                                         13
# Qatar                                           13
# Maldives                                        13
# Zambia                                          12
# Rwanda                                          12
# Oman                                            11
# Libyan Arab Jamahiriya                          10
# Antigua and Barbuda                              9
# Swaziland                                        8
# Congo, Republic of the...                        7
# Turkmenistan                                     7
# Democratic Republic of the Congo                 7
# Tajikistan                                       7
# Mauritania                                       7
# Mozambique                                       7
# Andorra                                          7
# Botswana                                         5
# Benin                                            5
# Angola                                           5
# Namibia                                          5
# Haiti                                            5
# Fiji                                             5
# Burkina Faso                                     4
# Monaco                                           4
# Togo                                             4
# Mali                                             3
# Bahamas                                          3
# Lesotho                                          3
# Barbados                                         3
# Belize                                           3
# Cape Verde                                       3
# Democratic People's Republic of Korea            3
# Guinea                                           3
# Liechtenstein                                    3
# Guyana                                           3
# Lao People's Democratic Republic                 3
# Burundi                                          3
# Gabon                                            2
# Bhutan                                           2
# Djibouti                                         2
# Liberia                                          2
# Malawi                                           2
# San Marino                                       2
# Seychelles                                       2
# Sierra Leone                                     2
# Saint Kitts and Nevis                            1
# Sao Tome and Principe                            1
# Saint Vincent and the Grenadines                 1
# Niger                                            1
# Papua New Guinea                                 1
# Dominica                                         1
# Tonga                                            1
# Timor-Leste                                      1
# North Korea                                      1
# Brunei Darussalam                                1
# Chad                                             1
# Name: count, dtype: int64

# %%
# How many developers use Python Worldwide?

# %%
world_python = df[df['PythonUser'] == True]['Country']
world_python_count = world_python.value_counts()
print(world_python_count.to_string())
print(f'Name: PythonUser, dtype: {world_python_count.dtype}')
# Out:
# Country
# United States                                10083
# India                                         3105
# Germany                                       2451
# United Kingdom                                2384
# Canada                                        1558
# France                                        1054
# Australia                                      790
# Netherlands                                    767
# Brazil                                         767
# Poland                                         751
# Russian Federation                             708
# Spain                                          641
# Italy                                          625
# Sweden                                         496
# Switzerland                                    460
# Israel                                         457
# Turkey                                         371
# Austria                                        338
# China                                          297
# Belgium                                        296
# Czech Republic                                 285
# Iran                                           268
# Finland                                        266
# Romania                                        253
# Pakistan                                       251
# Ukraine                                        246
# Denmark                                        246
# Mexico                                         245
# New Zealand                                    236
# Norway                                         232
# Greece                                         226
# Ireland                                        209
# Bangladesh                                     204
# South Africa                                   202
# Hungary                                        191
# Argentina                                      191
# Portugal                                       182
# Japan                                          182
# Bulgaria                                       181
# Nigeria                                        152
# Indonesia                                      148
# Singapore                                      139
# Sri Lanka                                      137
# Kenya                                          120
# Slovenia                                       119
# Philippines                                    117
# Serbia                                         117
# Egypt                                          111
# Colombia                                       108
# Chile                                          102
# Slovakia                                       101
# Nepal                                          101
# Malaysia                                        95
# Thailand                                        92
# Taiwan                                          88
# Hong Kong (S.A.R.)                              88
# Croatia                                         87
# Estonia                                         82
# South Korea                                     80
# Lithuania                                       79
# Viet Nam                                        78
# Belarus                                         69
# Morocco                                         50
# United Arab Emirates                            49
# Uganda                                          47
# Peru                                            47
# Lebanon                                         42
# Algeria                                         40
# Tunisia                                         40
# Ecuador                                         39
# Latvia                                          39
# Other Country (Not Listed Above)                37
# Uruguay                                         36
# Saudi Arabia                                    33
# Ghana                                           32
# Costa Rica                                      30
# Iceland                                         30
# Bosnia and Herzegovina                          29
# Armenia                                         28
# Venezuela, Bolivarian Republic of...            28
# Georgia                                         26
# Luxembourg                                      25
# Guatemala                                       25
# Albania                                         23
# Jordan                                          22
# Dominican Republic                              21
# Republic of Korea                               20
# Cyprus                                          20
# Ethiopia                                        20
# Malta                                           20
# El Salvador                                     19
# Paraguay                                        19
# Iraq                                            17
# Azerbaijan                                      17
# Sudan                                           16
# Cameroon                                        16
# Cuba                                            16
# United Republic of Tanzania                     15
# Kazakhstan                                      15
# Uzbekistan                                      14
# Zimbabwe                                        14
# Panama                                          13
# Honduras                                        12
# Côte d'Ivoire                                   11
# Bolivia                                         11
# Nicaragua                                       10
# Myanmar                                          9
# Cambodia                                         9
# Afghanistan                                      8
# Mauritius                                        8
# Senegal                                          8
# Mongolia                                         8
# The former Yugoslav Republic of Macedonia        8
# Jamaica                                          8
# Montenegro                                       8
# Syrian Arab Republic                             7
# Republic of Moldova                              7
# Turkmenistan                                     6
# Kyrgyzstan                                       6
# Oman                                             6
# Kuwait                                           6
# Maldives                                         6
# Qatar                                            5
# Mauritania                                       5
# Rwanda                                           5
# Trinidad and Tobago                              5
# Zambia                                           4
# Congo, Republic of the...                        4
# Bahrain                                          4
# Madagascar                                       4
# Haiti                                            3
# Democratic Republic of the Congo                 3
# Somalia                                          3
# Benin                                            3
# Namibia                                          3
# Yemen                                            3
# Guinea                                           2
# Guyana                                           2
# Bahamas                                          2
# Libyan Arab Jamahiriya                           2
# Monaco                                           2
# Angola                                           2
# Swaziland                                        2
# Lesotho                                          1
# Sao Tome and Principe                            1
# Mozambique                                       1
# Botswana                                         1
# Bhutan                                           1
# San Marino                                       1
# Togo                                             1
# Seychelles                                       1
# Belize                                           1
# Burundi                                          1
# Barbados                                         1
# Dominica                                         1
# Niger                                            1
# Fiji                                             1
# Timor-Leste                                      1
# Mali                                             1
# Sierra Leone                                     1
# Liechtenstein                                    1
# Democratic People's Republic of Korea            1
# Name: PythonUser, dtype: int64

# %%
# Out:
# Country
# Afghanistan                                               20
# Albania                                                   30
# Algeria                                                   19
# Andorra                                                    4
# Angola                                                     5
# Argentina                                                246
# Armenia                                                   33
# Australia                                                831
# Austria                                                  377
# Azerbaijan                                                33
# Bahamas                                                    5
# Bahrain                                                   14
# Bangladesh                                               322
# Barbados                                                   4
# Belarus                                                   46
# Belgium                                                  333
# Belize                                                     3
# Benin                                                      4
# Bhutan                                                     3
# Bolivia                                                   17
# Bosnia and Herzegovina                                    47
# Botswana                                                   2
# Brazil                                                   951
# Brunei Darussalam                                          1
# Bulgaria                                                 117
# Burkina Faso                                               3
# Burundi                                                    4
# Cambodia                                                  10
# Cameroon                                                  16
# Canada                                                  1593
# Cape Verde                                                 3
# Central African Republic                                   1
# Chad                                                       1
# Chile                                                    123
# China                                                    495
# Colombia                                                 176
# Congo, Republic of the...                                  4
# Costa Rica                                                30
# Croatia                                                  109
# Cuba                                                      22
# Cyprus                                                    26
# Czech Republic                                           367
# Côte d'Ivoire                                              6
# Democratic Republic of the Congo                           5
# Denmark                                                  273
# Djibouti                                                   1
# Dominica                                                   1
# Dominican Republic                                        29
# Ecuador                                                   49
# Egypt                                                    218
# El Salvador                                               10
# Estonia                                                   61
# Ethiopia                                                  30
# Fiji                                                       1
# Finland                                                  247
# France                                                  1423
# Gambia                                                     1
# Georgia                                                   59
# Germany                                                 2713
# Ghana                                                     38
# Greece                                                   295
# Guatemala                                                 26
# Guinea                                                     1
# Guyana                                                     4
# Haiti                                                      3
# Honduras                                                  10
# Hong Kong (S.A.R.)                                       105
# Hungary                                                  209
# Iceland                                                   27
# India                                                   5233
# Indonesia                                                256
# Iran, Islamic Republic of...                             411
# Iraq                                                      27
# Ireland                                                  193
# Isle of Man                                                3
# Israel                                                   515
# Italy                                                    735
# Jamaica                                                   10
# Japan                                                    209
# Jordan                                                    22
# Kazakhstan                                                30
# Kenya                                                    132
# Kosovo                                                    12
# Kuwait                                                    12
# Kyrgyzstan                                                 4
# Lao People's Democratic Republic                           1
# Latvia                                                    38
# Lebanon                                                   48
# Lesotho                                                    0
# Liberia                                                    2
# Libyan Arab Jamahiriya                                     4
# Liechtenstein                                              1
# Lithuania                                                 59
# Luxembourg                                                26
# Madagascar                                                 7
# Malawi                                                     4
# Malaysia                                                 150
# Maldives                                                   9
# Mali                                                       0
# Malta                                                     17
# Mauritania                                                 2
# Mauritius                                                 17
# Mexico                                                   285
# Micronesia, Federated States of...                         1
# Monaco                                                     0
# Mongolia                                                  10
# Montenegro                                                 4
# Morocco                                                   95
# Mozambique                                                 3
# Myanmar                                                   15
# Namibia                                                    9
# Nepal                                                    178
# Netherlands                                              831
# New Zealand                                              230
# Nicaragua                                                  4
# Niger                                                      1
# Nigeria                                                  172
# Nomadic                                                   27
# North Korea                                                3
# Norway                                                   257
# Oman                                                      11
# Pakistan                                                 323
# Palestine                                                 13
# Panama                                                    11
# Papua New Guinea                                           0
# Paraguay                                                  17
# Peru                                                      72
# Philippines                                              155
# Poland                                                   812
# Portugal                                                 219
# Qatar                                                     20
# Republic of Korea                                         31
# Republic of Moldova                                       17
# Romania                                                  263
# Russian Federation                                       665
# Rwanda                                                    14
# Saint Kitts and Nevis                                      0
# Saint Lucia                                                2
# Saint Vincent and the Grenadines                           0
# San Marino                                                 0
# Saudi Arabia                                              63
# Senegal                                                   16
# Serbia                                                   109
# Sierra Leone                                               2
# Singapore                                                203
# Slovakia                                                 119
# Slovenia                                                 122
# Somalia                                                    3
# South Africa                                             247
# South Korea                                               86
# Spain                                                    676
# Sri Lanka                                                189
# Sudan                                                     12
# Suriname                                                   2
# Swaziland                                                  5
# Sweden                                                   525
# Switzerland                                              470
# Syrian Arab Republic                                      15
# Taiwan                                                   146
# Tajikistan                                                 2
# Thailand                                                  86
# The former Yugoslav Republic of Macedonia                 18
# Togo                                                       3
# Trinidad and Tobago                                        8
# Tunisia                                                   79
# Turkey                                                   463
# Turkmenistan                                               4
# Tuvalu                                                     1
# Uganda                                                    33
# Ukraine                                                  271
# United Arab Emirates                                      80
# United Kingdom of Great Britain and Northern Ireland    2149
# United Republic of Tanzania                               18
# United States of America                                7975
# Uruguay                                                   56
# Uzbekistan                                                31
# Venezuela, Bolivarian Republic of...                      43
# Viet Nam                                                 173
# Yemen                                                      6
# Zambia                                                    12
# Zimbabwe                                                  17
# Name: LanguageHaveWorkedWith, dtype: int64

# %%
count_and_python = pd.concat([df_participants[country_list], world_python_count[country_list]],
                             axis=1)
count_and_python.columns = ['Number of Respondents', 'Number of Python Users']
count_and_python.sort_values(by=['Number of Respondents'], ascending=False, inplace=True, ignore_index=False)
count_and_python
# Out:
#                 Number of Respondents  Number of Python Users
# Country
# United States                   20949                   10083
# India                            9061                    3105
# Germany                          5866                    2451
# United Kingdom                   5737                    2384
# Canada                           3395                    1558
# France                           2391                    1054

# %%
#Concatinate the number of people who reponded to the survey
# to the one who know Python in one dataframe called python_df
# Out:
#                                                     count  \
# Country
# United States of America                            15288
# India                                               10511
# Germany                                              5625
# United Kingdom of Great Britain and Northern Ir...   4475
# Canada                                               3012
#
#                                                     LanguageHaveWorkedWith
# Country
# United States of America                                              7975
# India                                                                 5233
# Germany                                                               2713
# United Kingdom of Great Britain and Northern Ir...                    2149
# Canada                                                                1593

# %%
#Rename the columns
python_df.rename(columns={'Country':'TotalOfRespondents', 'LanguageHaveWorkedWith':'NumberKnowsPython', 'percentage':'PercentDevPython'}, inplace=True)

# %%
python_df.head(50)

# %%
df.rename(columns={'Country':'TotalOfRespondents', 'LanguageWorkedWith':'NumberKnowsPython', 'percentage':'PercentDevPython'}, inplace=True)

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'TotalOfRespondents', 'Student', 'EdLevel',
#        'UndergradMajor', 'EduOther', 'OrgSize', 'DevType', 'YearsCode',
#        'Age1stCode', 'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot',
#        'MgrMoney', 'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'NumberKnowsPython', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
#        'BlockchainOrg', 'BlockchainIs', 'BetterLife', 'ITperson', 'OffOn',
#        'SocialMedia', 'Extraversion', 'ScreenName', 'SOVisit1st',
#        'SOVisitFreq', 'SOVisitTo', 'SOFindAnswer', 'SOTimeSaved',
#        'SOHowMuchTime', 'SOAccount', 'SOPartFreq', 'SOJobs', 'EntTeams',
#        'SOComm', 'WelcomeChange', 'SONewContent', 'Age', 'Gender', 'Trans',
#        'Sexuality', 'Ethnicity', 'Dependents', 'SurveyLength', 'SurveyEase',
#        'PythonUser'],
#       dtype='object')

# %%
#Surprise me with some plot off this later dataframe


greece_df = df[df['Country']=='Greece']
greece_df

plt.rcParams["figure.figsize"] = (15,10)
sns.barplot(x = 'ConvertedCompYearly', y = 'Gender', data = df).set(title='Salaries of Developers Around The World, Based on Gender')
# sns.despine()
# plt.show()
plt.savefig('saving-a-seaborn-plot-as-pdf-file.png')

# %%
df.rename(columns={'TotalOfRespondents':'Country'}, inplace=True)

greece_df = df[df['Country']=='Greece']

plt.rcParams["figure.figsize"] = (15,10)
sns.barplot(x = 'ConvertedComp', y = 'Gender', data = df).set(title='Salaries of Developers Around The World, Based on Gender')
sns.despine()
plt.show()
plt.savefig('saving-a-seaborn-plot-as-pdf-file.png')

# %%
# !ls

# %% [markdown]
# # Good Job!

# %%
# !PWD
# Out:
# /Users/moussadoumbia/Desktop/23ACADEMY/I.T/FALL22_DS
